# %% [markdown]
# # Week 4: Data transformation, cleaning and loading with Python
#
# The following tutorial assumes a bit of background on SQL, in particular on its core commands
# to create new tables and to retrieve data:
#
#  SQL Command   |  Meaning
#  --------------|------------
#  SELECT COUNT(\*) FROM *T*   | count how many tuples are stored in table *T*
#  SELECT \* FROM *T*          | list the content of table *T*
#
# You can learn more background on these SQL commands in the [Ed lessons on SQL][1] (Module 16 onwards).
#
#   [1]: https://edstem.org/au/courses/14365/lessons/
#
# ## Water Dataset
# We are considering a water dataset this week about Murray River Basin in NSW. On Canvas (Module 4 section), there are four different CSV files. Please put them under the same folder as this notebook first.
#
# **Important:** Make sure that the naming of all the files is as follows:
#  1. Measurements.csv
#  2. Organisations.csv
#  3. Sensors.csv
#  4. Stations.csv

# %% [markdown]
# # EXERCISE 1: Data Loading and Database Creation with Python
#
# We will use the `DictReader` from the `csv` module which support reading and writing of files in comma-separated values (CSV).
#
# We will first load the content of the 'Organisations.csv' CSV file into Python with the csv.DictReader()  mechanism:

# %%
import csv
data_organisations = list(csv.DictReader(open('Organisations.csv')))
print(data_organisations[0])
# Out:
# {'Code': 'DNR', 'Organisation': 'NSW Department of Water and Energy (and predecessors)'}

# %% [markdown]
# For larger data sets, the following would normally be executed as a stand alone Python program on a shell.
# First, you need to establish a connection to the postgresql database.
# __Please edit the YOUR_DBNAME, YOUR_USERNAME and YOUR_PW variables in below's code to match your database login.__

# %%
import psycopg2

def pgconnect():
    # please replace with your own details
    YOUR_DBNAME = 'postgres'    # 直接看database 名字就好
    YOUR_USERNAME = 'postgres'  # 要在server的setting里面看
    YOUR_PW     = 'qq56523734'
    try: 
        conn = psycopg2.connect(host='localhost',
                                database=YOUR_DBNAME,
                                user=YOUR_USERNAME, 
                                password=YOUR_PW)
        print('connected')
    except Exception as e:
        print("unable to connect to the database")
        print(e)
    return conn

# %% [markdown]
# We will need to execute some SQL statements against the database. As we will have to do so multiple times, we write a dedicated function for executing an arbitrary SQL statement, where we do not expect any result. This handles all failures and using psycopg2's 'with' statements also handles the transaction processing of the database. Below's code will for example automatically commit our SQL statements, as well as rollback if there was any error.

# %%
def pgexec( conn, sqlcmd, args, msg, silent=False ):
   """ utility function to execute some SQL statement
       can take optional arguments to fill in (dictionary)
       error and transaction handling built-in """
   retval = False
   with conn:
      with conn.cursor() as cur:
         try:
            if args is None:
               cur.execute(sqlcmd)
            else:
               cur.execute(sqlcmd, args)
            if silent == False: 
                print("success: " + msg)
            retval = True
         except Exception as e:
            if silent == False: 
                print("db error: ")
                print(e)
   return retval

# %% [markdown]
# Now let's load our previous data.
# Important: whenever you use this approach, make sure that the header line of your CSV file has no spaces in its column titles and also no quotes. Otherwise, the csv.DictReader might be fine to read it, but not the psycopg2's cursor.execute() function. We are using named placeholders in our INSERT statement below (eg. '%(Code)s' ) which expects to put a string (%s) into that place of the INSERT statement as been found in the given dictionary for the execute() call with the key 'Code'.

# %%
# 1st: login to database
conn = pgconnect()

# if you want to reset the table
pgexec (conn, "DROP TABLE IF EXISTS Organisation CASCADE", None, "Reset Table Organisation")

# 2nd: ensure that the schema is in place
organisation_schema = """CREATE TABLE IF NOT EXISTS Organisation (
                         code VARCHAR(20) PRIMARY KEY,
                         orgName VARCHAR(150)
                   )"""
pgexec (conn, organisation_schema, None, "Create Table Organisation")

# 3rd: load data
# IMPORTANT: make sure the header line of CSV is without spaces!
insert_stmt = """INSERT INTO Organisation(code,orgName) VALUES (%(Code)s, %(Organisation)s)"""
for i, row in enumerate(data_organisations):
    pgexec (conn, insert_stmt, row, f"Row {i+1} inserted")

# 4th: keep in mind to close connection
conn.close()
# Out:
# connected
# success: Reset Table Organisation
# success: Create Table Organisation
# success: Row 1 inserted
# success: Row 2 inserted
# success: Row 3 inserted
# success: Row 4 inserted
# success: Row 5 inserted
# success: Row 6 inserted
# success: Row 7 inserted
# success: Row 8 inserted
# success: Row 9 inserted

# %% [markdown]
# Next let's check whether this has all worked fine by querying our PostgreSQL database. To do so, we first introduce another utility function which again encapsulates all error and transaction handling. Then we query the new Organisation table and simply print out all tuples found.

# %%
def pgquery( conn, sqlcmd, args, silent=False ):
   """ utility function to execute some SQL query statement
       can take optional arguments to fill in (dictionary)
       will print out on screen the result set of the query
       error and transaction handling built-in """
   retval = False
   with conn:
      with conn.cursor() as cur:
         try:
            if args is None:
                cur.execute(sqlcmd)
            else:
                cur.execute(sqlcmd, args)
            if silent == False:
                for record in cur:
                    print(record)
            retval = True
         except Exception as e:
            if silent == False:
                print("db read error: ")
                print(e)
   return retval

# %%
# check content of Organisation table
conn = pgconnect()
query_stmt = "SELECT * FROM Organisation"
print(query_stmt)
pgquery (conn, query_stmt, None)
conn.close()
# Out:
# connected
# SELECT * FROM Organisation
# ('DNR', 'NSW Department of Water and Energy (and predecessors)')
# ('DWR', 'NSW Department of Water and Energy (and predecessors)')
# ('MIL', 'Murray Irrigation Ltd')
# ('PWD', 'Manly Hydraulics Laboratory')
# ('QWR', 'Qld Department of Natural Resources and Water')
# ('SCA', 'Sydney Catchment Authority')
# ('SMA', 'Snowy Mountains Authority')
# ('SWB', 'Sydney Catchment Authority')
# ('VRW', 'Vic Government')

# %% [markdown]
# ## Your Task: Data Loading
#
# Try to create and load the Measurements table.
#
#     1. Read the Measurements csv file
#     2. Create a matching 'Measurement' table to hold the CSV data
#     3. Load the content of the csv file into a local 'data_measurements' dictionary in Python
#     4. Load the data from the 'data_measurements' dictionary into your PostgreSQL table
#     5. Query and print its content

# %%
# TODO: replace the content of this cell with your Python + psycopg2 solution
# raise NotImplementedError

data_measurements = list(csv.DictReader(open('Measurements.csv')))
print(data_measurements[0])

# 1st: login to database
conn = pgconnect()

# if you want to reset the table
pgexec (conn, "DROP TABLE IF EXISTS Measurement CASCADE", None, "Reset Table Measurement")

# 2nd: ensure that the schema is in place
measurement_schema = """CREATE TABLE IF NOT EXISTS Measurement (
                         station VARCHAR(20), 
                         date DATE, 
                         level VARCHAR(20), 
                         meanDischarge VARCHAR(20), 
                         discharge VARCHAR(20), 
                         temp VARCHAR(20), 
                         ec VARCHAR(20)
                   )"""
pgexec (conn, measurement_schema, None, "Create Table Measurement")

# 3rd: load data
# IMPORTANT: make sure the header line of CSV is without spaces!
insert_stmt = """INSERT INTO Measurement(station,date,level,meandischarge,discharge,temp,ec)
                      VALUES (%(Station)s, %(Date)s, %(Level)s,%(MeanDischarge)s,%(Discharge)s,%(Temp)s,%(EC)s)"""
for i, row in enumerate(data_measurements):
    pgexec (conn, insert_stmt, row, f"Row {i+1} inserted")
    
# 4th: keep in mind to close connection
conn.close()
# Out:
# {'Station': '409204C', 'Date': '31-Dec-04', 'Level': '1.196', 'MeanDischarge': '5876.087', 'Discharge': '5873.837', 'Temp': '23.217', 'EC': '57.583'}
# connected
# success: Reset Table Measurement
# success: Create Table Measurement
# success: Row 1 inserted
# success: Row 2 inserted
# success: Row 3 inserted
# success: Row 4 inserted
# success: Row 5 inserted
# success: Row 6 inserted
# success: Row 7 inserted
# success: Row 8 inserted
# success: Row 9 inserted
# success: Row 10 inserted
# success: Row 11 inserted
# success: Row 12 inserted
# success: Row 13 inserted
# success: Row 14 inserted
# success: Row 15 inserted
# success: Row 16 inserted
# success: Row 17 inserted
# success: Row 18 inserted
# success: Row 19 inserted
# success: Row 20 inserted
# success: Row 21 inserted
# success: Row 22 inserted
# success: Row 23 inserted
# success: Row 24 inserted
# success: Row 25 inserted
# success: Row 26 inserted
# success: Row 27 inserted
# success: Row 28 inserted
# success: Row 29 inserted
# success: Row 30 inserted
# success: Row 31 inserted
# success: Row 32 inserted
# success: Row 33 inserted
# success: Row 34 inserted
# success: Row 35 inserted
# success: Row 36 inserted
# success: Row 37 inserted
# success: Row 38 inserted
# success: Row 39 inserted
# success: Row 40 inserted
# success: Row 41 inserted
# success: Row 42 inserted
# success: Row 43 inserted
# success: Row 44 inserted
# success: Row 45 inserted
# success: Row 46 inserted
# success: Row 47 inserted
# success: Row 48 inserted
# success: Row 49 inserted
# success: Row 50 inserted
# success: Row 51 inserted
# success: Row 52 inserted
# success: Row 53 inserted
# success: Row 54 inserted
# success: Row 55 inserted
# success: Row 56 inserted
# success: Row 57 inserted
# success: Row 58 inserted
# success: Row 59 inserted
# success: Row 60 inserted
# success: Row 61 inserted
# success: Row 62 inserted
# success: Row 63 inserted
# success: Row 64 inserted
# success: Row 65 inserted
# success: Row 66 inserted
# success: Row 67 inserted
# success: Row 68 inserted
# success: Row 69 inserted
# success: Row 70 inserted
# success: Row 71 inserted
# success: Row 72 inserted
# success: Row 73 inserted
# success: Row 74 inserted
# success: Row 75 inserted
# success: Row 76 inserted
# success: Row 77 inserted
# success: Row 78 inserted
# success: Row 79 inserted
# success: Row 80 inserted
# success: Row 81 inserted
# success: Row 82 inserted
# success: Row 83 inserted
# success: Row 84 inserted
# success: Row 85 inserted
# success: Row 86 inserted
# success: Row 87 inserted
# success: Row 88 inserted
# success: Row 89 inserted
# success: Row 90 inserted
# success: Row 91 inserted
# success: Row 344 inserted
# success: Row 345 inserted
# success: Row 346 inserted
# success: Row 347 inserted
# success: Row 348 inserted
# success: Row 349 inserted
# success: Row 350 inserted
# success: Row 351 inserted
# success: Row 352 inserted
# success: Row 353 inserted
# success: Row 354 inserted
# success: Row 355 inserted
# success: Row 356 inserted
# success: Row 357 inserted
# success: Row 358 inserted
# success: Row 359 inserted
# success: Row 360 inserted
# success: Row 361 inserted
# success: Row 362 inserted
# success: Row 363 inserted
# success: Row 364 inserted
# success: Row 365 inserted
# success: Row 366 inserted
# success: Row 367 inserted
# success: Row 368 inserted
# success: Row 369 inserted
# success: Row 370 inserted
# success: Row 371 inserted
# success: Row 372 inserted
# success: Row 373 inserted
# success: Row 374 inserted
# success: Row 375 inserted
# success: Row 376 inserted
# success: Row 377 inserted
# success: Row 378 inserted
# success: Row 379 inserted
# success: Row 380 inserted
# success: Row 381 inserted
# success: Row 382 inserted
# success: Row 383 inserted
# success: Row 384 inserted
# success: Row 385 inserted
# success: Row 386 inserted
# success: Row 387 inserted
# success: Row 388 inserted
# success: Row 389 inserted
# success: Row 390 inserted
# success: Row 391 inserted
# success: Row 392 inserted
# success: Row 393 inserted
# success: Row 394 inserted
# success: Row 395 inserted
# success: Row 396 inserted
# success: Row 397 inserted
# success: Row 398 inserted
# success: Row 399 inserted
# success: Row 400 inserted
# success: Row 401 inserted
# success: Row 402 inserted
# success: Row 403 inserted
# success: Row 404 inserted
# success: Row 405 inserted
# success: Row 406 inserted
# success: Row 407 inserted
# success: Row 408 inserted
# success: Row 409 inserted
# success: Row 410 inserted
# success: Row 411 inserted
# success: Row 412 inserted
# success: Row 413 inserted
# success: Row 414 inserted
# success: Row 415 inserted
# success: Row 416 inserted
# success: Row 417 inserted
# success: Row 418 inserted
# success: Row 419 inserted
# success: Row 420 inserted
# success: Row 421 inserted
# success: Row 422 inserted
# success: Row 423 inserted
# success: Row 424 inserted
# success: Row 425 inserted
# success: Row 426 inserted
# success: Row 427 inserted
# success: Row 428 inserted
# success: Row 429 inserted
# success: Row 430 inserted
# success: Row 431 inserted

# %% [markdown]
# # STOP PLEASE. THE FOLLOWING IS FOR THE NEXT EXERCISE. THANKS.

# %% [markdown]
# ## EXERCISE 2: Data Cleaning
#
# ### Data Cleaning
# We use the following clean() function.

# %%
import numpy as np
DEFAULT_VALUE = np.nan

def clean(data, column_key, convert_function, default_value):
    special_values= {} # no special values yet
    for row in data:
        old_value = row[column_key]
        new_value = default_value
        try:
            if old_value in special_values.keys():
                new_value = special_values[old_value]
            else:
                new_value = convert_function(old_value)
        except (ValueError, TypeError):
            print(f'Replacing {old_value} with {new_value} in column {column_key}')
            special_values[old_value] = new_value
        row[column_key] = new_value

# %%
# this conversion strips any leading or trailing spaces from the 'Station' values
clean(data_measurements, 'Station', str.strip, DEFAULT_VALUE)

# the following converts the measurment columns to float values - or NaN
clean(data_measurements, 'Level', float, DEFAULT_VALUE)
clean(data_measurements, 'MeanDischarge', float, DEFAULT_VALUE)
clean(data_measurements, 'Discharge', float, DEFAULT_VALUE)
clean(data_measurements, 'Temp', float, DEFAULT_VALUE)
clean(data_measurements, 'EC', float, DEFAULT_VALUE)

## now we insert the  data_measurements into the 'Measurement' table 
# 1st: login to database
conn = pgconnect()

# 2nd: ensure that the schema is in place
pgexec (conn, "DROP TABLE IF EXISTS Measurement CASCADE", None, "Reset Table Measurement")
measurement_schema = """CREATE TABLE IF NOT EXISTS Measurement (
                         station   VARCHAR(20),
                         date DATE,
                         level  FLOAT,
                         meanDischarge FLOAT,
                         discharge  FLOAT,
                         temp FLOAT,
                         ec  FLOAT
                      )"""
pgexec (conn, measurement_schema, None, "Create Table Measurement")

# 3rd: load data
# IMPORTANT: make sure the header line of CSV is without spaces!
insert_stmt = """INSERT INTO Measurement(station,date,level,meandischarge,discharge,temp,ec)
                      VALUES (%(Station)s,%(Date)s,%(Level)s,%(MeanDischarge)s,%(Discharge)s,%(Temp)s,%(EC)s)"""
for i, row in enumerate(data_measurements):
    pgexec (conn, insert_stmt, row, f"Row {i+1} inserted")
    
query_stmt = "SELECT COUNT(*) FROM Measurement"
print(query_stmt)
pgquery (conn, query_stmt, None)

# 4th: keep in mind to close connection
conn.close()
# Out:
# Replacing x with nan in column Level
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column Discharge
# Replacing x with nan in column Temp
# Replacing x with nan in column EC
# connected
# success: Reset Table Measurement
# success: Create Table Measurement
# success: Row 1 inserted
# success: Row 2 inserted
# success: Row 3 inserted
# success: Row 4 inserted
# success: Row 5 inserted
# success: Row 6 inserted
# success: Row 7 inserted
# success: Row 8 inserted
# success: Row 9 inserted
# success: Row 10 inserted
# success: Row 11 inserted
# success: Row 12 inserted
# success: Row 13 inserted
# success: Row 14 inserted
# success: Row 15 inserted
# success: Row 16 inserted
# success: Row 17 inserted
# success: Row 18 inserted
# success: Row 19 inserted
# success: Row 20 inserted
# success: Row 21 inserted
# success: Row 22 inserted
# success: Row 23 inserted
# success: Row 24 inserted
# success: Row 25 inserted
# success: Row 26 inserted
# success: Row 27 inserted
# success: Row 28 inserted
# success: Row 29 inserted
# success: Row 30 inserted
# success: Row 31 inserted
# success: Row 32 inserted
# success: Row 33 inserted
# success: Row 34 inserted
# success: Row 35 inserted
# success: Row 36 inserted
# success: Row 37 inserted
# success: Row 38 inserted
# success: Row 39 inserted
# success: Row 40 inserted
# success: Row 41 inserted
# success: Row 42 inserted
# success: Row 43 inserted
# success: Row 44 inserted
# success: Row 45 inserted
# success: Row 46 inserted
# success: Row 47 inserted
# success: Row 48 inserted
# success: Row 49 inserted
# success: Row 50 inserted
# success: Row 51 inserted
# success: Row 52 inserted
# success: Row 53 inserted
# success: Row 54 inserted
# success: Row 55 inserted
# success: Row 56 inserted
# success: Row 57 inserted
# success: Row 58 inserted
# success: Row 59 inserted
# success: Row 60 inserted
# success: Row 61 inserted
# success: Row 62 inserted
# success: Row 63 inserted
# success: Row 64 inserted
# success: Row 65 inserted
# success: Row 318 inserted
# success: Row 319 inserted
# success: Row 320 inserted
# success: Row 321 inserted
# success: Row 322 inserted
# success: Row 323 inserted
# success: Row 324 inserted
# success: Row 325 inserted
# success: Row 326 inserted
# success: Row 327 inserted
# success: Row 328 inserted
# success: Row 329 inserted
# success: Row 330 inserted
# success: Row 331 inserted
# success: Row 332 inserted
# success: Row 333 inserted
# success: Row 334 inserted
# success: Row 335 inserted
# success: Row 336 inserted
# success: Row 337 inserted
# success: Row 338 inserted
# success: Row 339 inserted
# success: Row 340 inserted
# success: Row 341 inserted
# success: Row 342 inserted
# success: Row 343 inserted
# success: Row 344 inserted
# success: Row 345 inserted
# success: Row 346 inserted
# success: Row 347 inserted
# success: Row 348 inserted
# success: Row 349 inserted
# success: Row 350 inserted
# success: Row 351 inserted
# success: Row 352 inserted
# success: Row 353 inserted
# success: Row 354 inserted
# success: Row 355 inserted
# success: Row 356 inserted
# success: Row 357 inserted
# success: Row 358 inserted
# success: Row 359 inserted
# success: Row 360 inserted
# success: Row 361 inserted
# success: Row 362 inserted
# success: Row 363 inserted
# success: Row 364 inserted
# success: Row 365 inserted
# success: Row 366 inserted
# success: Row 367 inserted
# success: Row 368 inserted
# success: Row 369 inserted
# success: Row 370 inserted
# success: Row 371 inserted
# success: Row 372 inserted
# success: Row 373 inserted
# success: Row 374 inserted
# success: Row 375 inserted
# success: Row 376 inserted
# success: Row 377 inserted
# success: Row 378 inserted
# success: Row 379 inserted
# success: Row 380 inserted
# success: Row 381 inserted
# success: Row 382 inserted
# success: Row 383 inserted
# success: Row 384 inserted
# success: Row 385 inserted
# success: Row 386 inserted
# success: Row 387 inserted
# success: Row 388 inserted
# success: Row 389 inserted
# success: Row 390 inserted
# success: Row 391 inserted
# success: Row 392 inserted
# success: Row 393 inserted
# success: Row 394 inserted
# success: Row 395 inserted
# success: Row 396 inserted
# success: Row 397 inserted
# success: Row 398 inserted
# success: Row 399 inserted
# success: Row 400 inserted
# success: Row 401 inserted
# success: Row 402 inserted
# success: Row 403 inserted
# success: Row 404 inserted
# success: Row 405 inserted
# success: Row 406 inserted
# success: Row 407 inserted
# success: Row 408 inserted
# success: Row 409 inserted
# success: Row 410 inserted
# success: Row 411 inserted
# success: Row 412 inserted
# success: Row 413 inserted
# success: Row 414 inserted
# success: Row 415 inserted
# success: Row 416 inserted
# success: Row 417 inserted
# success: Row 418 inserted
# success: Row 419 inserted
# success: Row 420 inserted
# success: Row 421 inserted
# success: Row 422 inserted
# success: Row 423 inserted
# success: Row 424 inserted
# success: Row 425 inserted
# success: Row 426 inserted
# success: Row 427 inserted
# success: Row 428 inserted
# success: Row 429 inserted
# success: Row 430 inserted
# success: Row 431 inserted
# SELECT COUNT(*) FROM Measurement
# (431,)

# %% [markdown]
# ## Your Task: Data Cleaning
#
# Use above's  clean()  function to clean the other datasets too.
#  1. Read the Stations csv file into data_stations
#  2. Clean the  'data_stations'  data set
#  3. Load the 'data_stations'  dictionary into your database
#  4. Query the 'Stations' table - what difference do you see?
#
#  5. If you have time: Do all of the above (reading - cleaning - loading) also for the 'Sensors.csv' data set

# %% [markdown]
# Note: You might encounter a few warning and error messages.
#    - If a connection is closed, you have to open the databse connection again first
#    - If the clean() function returns a warning that some string was replaced with NaN, as long as this is indeed a number attribute, you are Ok to ignore this message. It just tells you that it is doing what it is supposed to do.
#    - If you try to insert data into an already existing table with data inside, you might get 'duplicate primary key' error messages. Again, you can ignore those for the moment.
#    - If you want to see how much data is already in your table, use the following SQL query:
#      -  SELECT COUNT(*) FROM Station;

# %%
# TODO: replace the content of this cell with your Python solution
# raise NotImplementedError

import csv

data_stations = list(csv.DictReader(open('Stations.csv')))
print(data_stations[0])

# 1st: login to database
conn = pgconnect()

# if you want to reset the table
pgexec (conn, "DROP TABLE IF EXISTS Station CASCADE", None, "Reset Table Station")
# 2nd: ensure that the schema is in place
stations_schema = """CREATE TABLE IF NOT EXISTS Station (
                         station VARCHAR(20) PRIMARY KEY, 
                         siteName VARCHAR(150), 
                         commence DATE, 
                         orgCode VARCHAR(20)
                   )"""


pgexec (conn, stations_schema, None, "Create Table Station")
pgexec (conn, "SET datestyle = 'ISO,DMY'; ", None, "Modify datestyle")

# 3rd: load data
# IMPORTANT: make sure the header line of CSV is without spaces!
insert_stmt = """INSERT INTO Station(station, siteName,commence,orgCode)
                      VALUES (%(Station)s, %(SiteName)s, %(Commence)s, %(OrgCode)s)"""

stationData = dict()
for i, row in enumerate(data_stations):
    stationData['Station'] = row['BasinNo']+row['Site']
    stationData['SiteName']  = row['SiteName']
    stationData['Commence'] = row['Commence']
    stationData['OrgCode'] = row['OrgCode']
    
    pgexec (conn, insert_stmt, stationData, f"Row {i+1} inserted")

query_stmt = "SELECT * FROM Station"
print(query_stmt)
pgquery (conn, query_stmt, None)

# 4th: keep in mind to close connection
conn.close()
# Out:
# {'BasinNo': '409', 'Site': '001', 'SiteName': 'Murray River at Albury (Union Bridge)', 'Long': '146.8957 E', 'Lat': '36.0929 S', 'Commence': '14/04/1892', 'OrgCode': 'DWR'}
# connected
# success: Reset Table Station
# success: Create Table Station
# success: Modify datestyle
# success: Row 1 inserted
# success: Row 2 inserted
# success: Row 3 inserted
# success: Row 4 inserted
# success: Row 5 inserted
# success: Row 6 inserted
# success: Row 7 inserted
# success: Row 8 inserted
# success: Row 9 inserted
# SELECT * FROM Station
# ('409001', 'Murray River at Albury (Union Bridge)', datetime.date(1892, 4, 14), 'DWR')
# ('409002', 'Murray River at Corowa', datetime.date(1894, 4, 1), 'DWR')
# ('409003', 'Murray River at Denuquin', datetime.date(1896, 9, 1), 'DWR')
# ('409005', 'Murray River at Barham', datetime.date(1900, 12, 31), 'DWR')
# ('409204C', 'Murray River @ Swan Hill', datetime.date(1904, 12, 31), 'VRW')
# ('409017', 'Murray River @ Doctors Point', datetime.date(1925, 8, 22), 'DWR')
# ('409019', 'Wakool River at Offtake Regulator', datetime.date(1931, 2, 7), 'DWR')
# ('409202', 'Murray River @ Tocumwal', datetime.date(1886, 6, 6), 'VRW')
# ('219018', 'Murray River @ Quaama', datetime.date(1962, 11, 7), 'DWR')

# %% [markdown]
# # STOP PLEASE. THE FOLLOWING IS FOR THE NEXT EXERCISE. THANKS.

# %% [markdown]
# ## EXERCISE 3: Database Creation
# The next step is to create the SQL schema (see below) in your PostgreSQL database.
#
# ### Your Task: DB Creation in PostgreSQL
# Create the corresponding tables in PostgreSQL which follow from the data model.

# %% [markdown]
# <pre>
# DROP TABLE IF EXISTS Organisation CASCADE;
# CREATE TABLE IF NOT EXISTS Organisation (
#    code VARCHAR(20) PRIMARY KEY,
#    organisation    VARCHAR(150)
# );
#
# DROP TABLE IF EXISTS Station CASCADE;
# CREATE TABLE IF NOT EXISTS Station (
#      station   VARCHAR(50) PRIMARY KEY,
#      siteName  VARCHAR(50),
#      commence DATE,
#      orgCode  VARCHAR(50),
#      CONSTRAINT orgCodeFK FOREIGN KEY (orgCode)   REFERENCES Organisation (code)
#  );
#
# DROP TABLE IF EXISTS Sensor CASCADE;
# CREATE TABLE IF NOT EXISTS Sensor (
#      sensor   VARCHAR(20) PRIMARY KEY,
#      description  VARCHAR(150) ,
#      metric VARCHAR(20)
#   );
#
# DROP TABLE IF EXISTS Measurement CASCADE;
# CREATE TABLE IF NOT EXISTS Measurement (
#      station   VARCHAR(20),
#      sensor   VARCHAR(20),
#      date DATE,
#      value  FLOAT,
#      CONSTRAINT stationFK FOREIGN KEY (station)   REFERENCES Station (Station),
#      CONSTRAINT sensorFK FOREIGN KEY (sensor)   REFERENCES sensor (sensor)
#   );
# </pre>

# %%
# TODO: replace the content of this cell with your Python + SQL solution
# raise NotImplementedError

table_schema = """
DROP TABLE IF EXISTS Organisation CASCADE;
CREATE TABLE IF NOT EXISTS Organisation (
   code VARCHAR(20) PRIMARY KEY,
   organisation    VARCHAR(150)
);

DROP TABLE IF EXISTS Station CASCADE;
CREATE TABLE IF NOT EXISTS Station (
     station   VARCHAR(50) PRIMARY KEY,
     siteName  VARCHAR(50),
     commence DATE,
     orgCode  VARCHAR(50),
     CONSTRAINT orgCodeFK FOREIGN KEY (orgCode)   REFERENCES Organisation (code)
 );

DROP TABLE IF EXISTS Sensor CASCADE;
CREATE TABLE IF NOT EXISTS Sensor (
     sensor   VARCHAR(20) PRIMARY KEY,
     description  VARCHAR(150) ,       
     metric VARCHAR(20)                 
  );

DROP TABLE IF EXISTS Measurement CASCADE;
CREATE TABLE IF NOT EXISTS Measurement (
     station   VARCHAR(20),
     sensor   VARCHAR(20),
     date DATE,
     value  FLOAT,
     CONSTRAINT stationFK FOREIGN KEY (station)   REFERENCES Station (Station),
     CONSTRAINT sensorFK FOREIGN KEY (sensor)   REFERENCES sensor (sensor)
  );
"""
conn = pgconnect()
pgexec(conn, table_schema, None, "Created our data warehouse")
conn.close()
# Out:
# connected
# success: Created our data warehouse

# %% [markdown]
# # STOP PLEASE. THE FOLLOWING IS FOR THE NEXT EXERCISE. THANKS.

# %% [markdown]
# ## EXERCISE 4: Data Loading and Storage
#
# Up-to this point, we have
#  - analysed and modelled the given dataset
#  - created a corresponding relational star schema
#  - read the individual CSV files into Python dictionary data structures
#  - cleaned the raw data with regard to missing or inconsistent entries and data types
#
# The final step is to load this cleaned data into the corresponding tables of the star schema which we defined so far.
#
# For this to work, you probably will need to write some logic to load different parts of different data dictionaries (holding the content of CSV files) into different tables.

# %%
import numpy as np
import csv

# make sure we are still connected to database 
conn = pgconnect()

#####################
# Organisation table
data_organisations = list(csv.DictReader(open('Organisations.csv')))

# check for any existing content of the Organisations table
query_stmt = "SELECT COUNT(*) FROM Organisation"
print(query_stmt)
pgquery (conn, query_stmt, None)

# Try to load data - 9 tuples should be created
insert_stmt = """INSERT INTO Organisation(code,organisation) VALUES (%(Code)s, %(Organisation)s)"""
for i, row in enumerate(data_organisations):
    pgexec (conn, insert_stmt, row, f"Organisation {i+1} inserted")
    
#####################
# Station table    
data_stations = list(csv.DictReader(open('Stations.csv')))

# check for any existing content of the Station table
query_stmt = "SELECT COUNT(*) FROM Station"
print(query_stmt)
pgquery (conn, query_stmt, None)

pgexec(conn, "SET datestyle = 'ISO,DMY'; ", None, "Modify datestyle")

# IMPORTANT: make sure the header line of CSV is without spaces!
insert_stmt = """INSERT INTO Station(station,siteName,commence,orgCode)
                      VALUES (%(station)s, %(siteName)s, %(commence)s, %(orgCode)s)"""
stationData = dict()
for i, row in enumerate(data_stations):
    stationData['station'] = row['BasinNo']+row['Site']
    stationData['siteName']  = row['SiteName']
    stationData['commence'] = row['Commence']
    stationData['orgCode'] = row['OrgCode']
    pgexec (conn, insert_stmt, stationData, f"Station {i+1} inserted")

#####################
# Sensor table    
data_sensors = list(csv.DictReader(open('Sensors.csv')))

# check for any existing content of the Sensor table
query_stmt = "SELECT COUNT(*) FROM Sensor"
print(query_stmt)
pgquery (conn, query_stmt, None)

# IMPORTANT: make sure the header line of CSV is without spaces!
insert_stmt = """INSERT INTO Sensor(sensor,description,metric)
                      VALUES (%(sensor)s, %(description)s, %(metric)s)"""

for i, row in enumerate(data_sensors):
    pgexec (conn, insert_stmt, row, f"Sensor {i+1} inserted")

#####################
# Measurement table    
data_measurements = list(csv.DictReader(open('Measurements.csv')))

# this conversion strips any leading or trailing spaces from the 'Station' values
clean(data_measurements, 'Station', str.strip, DEFAULT_VALUE)

# the following converts the measurment columns to float values - or NaN
clean(data_measurements, 'Discharge', float, DEFAULT_VALUE)
clean(data_measurements, 'MeanDischarge', float, DEFAULT_VALUE)
clean(data_measurements, 'Level', float, DEFAULT_VALUE)
clean(data_measurements, 'Temp', float, DEFAULT_VALUE)
clean(data_measurements, 'EC', float, DEFAULT_VALUE)

# check for any existing content of the Measurement table
query_stmt = "SELECT COUNT(*) FROM Measurement"
print(query_stmt)
pgquery (conn, query_stmt, None)

# IMPORTANT: make sure the header line of CSV is without spaces!
insert_stmt = """INSERT INTO Measurement(station,date,sensor,value)
                      VALUES (%(station)s, %(date)s, %(sensor)s, %(value)s)"""

measurementData = dict()
sensorCodes = ['levl', 'disvol','disc','temp', 'ec']
sensor_columns = ['Level', 'MeanDischarge', 'Discharge','Temp', 'EC']
cnt = 1
for row in data_measurements:
    measurementData['station'] = row['Station']
    measurementData['date'] = row['Date']
    for i in range(len(sensorCodes)):
        if(np.isnan(row[sensor_columns[i]])):
            continue;
        measurementData['sensor'] = sensorCodes[i]
        measurementData['value']  = row[sensor_columns[i]]
        pgexec (conn, insert_stmt, measurementData, f"Measurement {cnt} inserted")
        cnt += 1

conn.close();
# Out:
# connected
# SELECT COUNT(*) FROM Organisation
# (0,)
# success: Organisation 1 inserted
# success: Organisation 2 inserted
# success: Organisation 3 inserted
# success: Organisation 4 inserted
# success: Organisation 5 inserted
# success: Organisation 6 inserted
# success: Organisation 7 inserted
# success: Organisation 8 inserted
# success: Organisation 9 inserted
# SELECT COUNT(*) FROM Station
# (0,)
# success: Modify datestyle
# success: Station 1 inserted
# success: Station 2 inserted
# success: Station 3 inserted
# success: Station 4 inserted
# success: Station 5 inserted
# success: Station 6 inserted
# success: Station 7 inserted
# success: Station 8 inserted
# success: Station 9 inserted
# SELECT COUNT(*) FROM Sensor
# (0,)
# success: Sensor 1 inserted
# success: Sensor 2 inserted
# success: Sensor 3 inserted
# success: Sensor 4 inserted
# success: Sensor 5 inserted
# success: Sensor 6 inserted
# success: Sensor 7 inserted
# Replacing x with nan in column Discharge
# Replacing x with nan in column MeanDischarge
# Replacing x with nan in column Level
# Replacing x with nan in column Temp
# Replacing x with nan in column EC
# SELECT COUNT(*) FROM Measurement
# (0,)
# success: Measurement 1 inserted
# success: Measurement 2 inserted
# success: Measurement 3 inserted
# success: Measurement 4 inserted
# success: Measurement 5 inserted
# success: Measurement 6 inserted
# success: Measurement 7 inserted
# success: Measurement 8 inserted
# success: Measurement 9 inserted
# success: Measurement 10 inserted
# success: Measurement 11 inserted
# success: Measurement 12 inserted
# success: Measurement 13 inserted
# success: Measurement 14 inserted
# success: Measurement 15 inserted
# success: Measurement 16 inserted
# success: Measurement 17 inserted
# success: Measurement 18 inserted
# success: Measurement 19 inserted
# success: Measurement 20 inserted
# success: Measurement 21 inserted
# success: Measurement 22 inserted
# success: Measurement 23 inserted
# success: Measurement 24 inserted
# success: Measurement 25 inserted
# success: Measurement 26 inserted
# success: Measurement 27 inserted
# success: Measurement 28 inserted
# success: Measurement 29 inserted
# success: Measurement 30 inserted
# success: Measurement 31 inserted
# success: Measurement 32 inserted
# success: Measurement 33 inserted
# success: Measurement 34 inserted
# success: Measurement 35 inserted
# success: Measurement 36 inserted
# success: Measurement 37 inserted
# success: Measurement 38 inserted
# success: Measurement 39 inserted
# success: Measurement 40 inserted
# success: Measurement 41 inserted
# success: Measurement 42 inserted
# success: Measurement 43 inserted
# success: Measurement 44 inserted
# success: Measurement 45 inserted
# success: Measurement 46 inserted
# success: Measurement 47 inserted
# success: Measurement 48 inserted
# success: Measurement 49 inserted
# success: Measurement 50 inserted
# success: Measurement 51 inserted
# success: Measurement 52 inserted
# success: Measurement 53 inserted
# success: Measurement 54 inserted
# success: Measurement 55 inserted
# success: Measurement 56 inserted
# success: Measurement 57 inserted
# success: Measurement 58 inserted
# success: Measurement 59 inserted
# success: Measurement 60 inserted
# success: Measurement 61 inserted
# success: Measurement 62 inserted
# success: Measurement 63 inserted
# success: Measurement 64 inserted
# success: Measurement 65 inserted
# success: Measurement 66 inserted
# success: Measurement 67 inserted
# success: Measurement 68 inserted
# success: Measurement 69 inserted
# success: Measurement 70 inserted
# success: Measurement 71 inserted
# success: Measurement 72 inserted
# success: Measurement 73 inserted
# success: Measurement 74 inserted
# success: Measurement 75 inserted
# success: Measurement 76 inserted
# success: Measurement 77 inserted
# success: Measurement 78 inserted
# success: Measurement 79 inserted
# success: Measurement 80 inserted
# success: Measurement 81 inserted
# success: Measurement 82 inserted
# success: Measurement 83 inserted
# success: Measurement 84 inserted
# success: Measurement 85 inserted
# success: Measurement 86 inserted
# success: Measurement 87 inserted
# success: Measurement 88 inserted
# success: Measurement 89 inserted
# success: Measurement 90 inserted
# success: Measurement 91 inserted
# success: Measurement 92 inserted
# success: Measurement 93 inserted
# success: Measurement 94 inserted
# success: Measurement 95 inserted
# success: Measurement 96 inserted
# success: Measurement 97 inserted
# success: Measurement 98 inserted
# success: Measurement 99 inserted
# success: Measurement 100 inserted
# success: Measurement 101 inserted
# success: Measurement 102 inserted
# success: Measurement 103 inserted
# success: Measurement 104 inserted
# success: Measurement 105 inserted
# success: Measurement 106 inserted
# success: Measurement 107 inserted
# success: Measurement 108 inserted
# success: Measurement 109 inserted
# success: Measurement 110 inserted
# success: Measurement 111 inserted
# success: Measurement 112 inserted
# success: Measurement 113 inserted
# success: Measurement 114 inserted
# success: Measurement 115 inserted
# success: Measurement 116 inserted
# success: Measurement 117 inserted
# success: Measurement 118 inserted
# success: Measurement 119 inserted
# success: Measurement 120 inserted
# success: Measurement 121 inserted
# success: Measurement 122 inserted
# success: Measurement 123 inserted
# success: Measurement 124 inserted
# success: Measurement 125 inserted
# success: Measurement 126 inserted
# success: Measurement 127 inserted
# success: Measurement 128 inserted
# success: Measurement 129 inserted
# success: Measurement 130 inserted
# success: Measurement 131 inserted
# success: Measurement 132 inserted
# success: Measurement 133 inserted
# success: Measurement 134 inserted
# success: Measurement 135 inserted
# success: Measurement 136 inserted
# success: Measurement 137 inserted
# success: Measurement 138 inserted
# success: Measurement 139 inserted
# success: Measurement 140 inserted
# success: Measurement 141 inserted
# success: Measurement 142 inserted
# success: Measurement 143 inserted
# success: Measurement 144 inserted
# success: Measurement 145 inserted
# success: Measurement 146 inserted
# success: Measurement 147 inserted
# success: Measurement 148 inserted
# success: Measurement 149 inserted
# success: Measurement 150 inserted
# success: Measurement 151 inserted
# success: Measurement 152 inserted
# success: Measurement 153 inserted
# success: Measurement 154 inserted
# success: Measurement 155 inserted
# success: Measurement 156 inserted
# success: Measurement 157 inserted
# success: Measurement 158 inserted
# success: Measurement 159 inserted
# success: Measurement 160 inserted
# success: Measurement 161 inserted
# success: Measurement 162 inserted
# success: Measurement 163 inserted
# success: Measurement 164 inserted
# success: Measurement 165 inserted
# success: Measurement 166 inserted
# success: Measurement 167 inserted
# success: Measurement 168 inserted
# success: Measurement 169 inserted
# success: Measurement 170 inserted
# success: Measurement 171 inserted
# success: Measurement 172 inserted
# success: Measurement 173 inserted
# success: Measurement 174 inserted
# success: Measurement 175 inserted
# success: Measurement 176 inserted
# success: Measurement 177 inserted
# success: Measurement 178 inserted
# success: Measurement 179 inserted
# success: Measurement 180 inserted
# success: Measurement 181 inserted
# success: Measurement 182 inserted
# success: Measurement 183 inserted
# success: Measurement 184 inserted
# success: Measurement 185 inserted
# success: Measurement 186 inserted
# success: Measurement 187 inserted
# success: Measurement 188 inserted
# success: Measurement 189 inserted
# success: Measurement 190 inserted
# success: Measurement 191 inserted
# success: Measurement 192 inserted
# success: Measurement 193 inserted
# success: Measurement 194 inserted
# success: Measurement 195 inserted
# success: Measurement 196 inserted
# success: Measurement 197 inserted
# success: Measurement 198 inserted
# success: Measurement 199 inserted
# success: Measurement 200 inserted
# success: Measurement 201 inserted
# success: Measurement 202 inserted
# success: Measurement 203 inserted
# success: Measurement 204 inserted
# success: Measurement 205 inserted
# success: Measurement 206 inserted
# success: Measurement 207 inserted
# success: Measurement 208 inserted
# success: Measurement 209 inserted
# success: Measurement 210 inserted
# success: Measurement 211 inserted
# success: Measurement 212 inserted
# success: Measurement 213 inserted
# success: Measurement 214 inserted
# success: Measurement 215 inserted
# success: Measurement 216 inserted
# success: Measurement 217 inserted
# success: Measurement 218 inserted
# success: Measurement 219 inserted
# success: Measurement 220 inserted
# success: Measurement 221 inserted
# success: Measurement 222 inserted
# success: Measurement 223 inserted
# success: Measurement 224 inserted
# success: Measurement 225 inserted
# success: Measurement 226 inserted
# success: Measurement 227 inserted
# success: Measurement 228 inserted
# success: Measurement 229 inserted
# success: Measurement 230 inserted
# success: Measurement 231 inserted
# success: Measurement 232 inserted
# success: Measurement 233 inserted
# success: Measurement 234 inserted
# success: Measurement 235 inserted
# success: Measurement 236 inserted
# success: Measurement 237 inserted
# success: Measurement 238 inserted
# success: Measurement 239 inserted
# success: Measurement 240 inserted
# success: Measurement 241 inserted
# success: Measurement 242 inserted
# success: Measurement 243 inserted
# success: Measurement 244 inserted
# success: Measurement 245 inserted
# success: Measurement 246 inserted
# success: Measurement 247 inserted
# success: Measurement 248 inserted
# success: Measurement 249 inserted
# success: Measurement 250 inserted
# success: Measurement 251 inserted
# success: Measurement 252 inserted
# success: Measurement 253 inserted
# success: Measurement 254 inserted
# success: Measurement 255 inserted
# success: Measurement 256 inserted
# success: Measurement 257 inserted
# success: Measurement 258 inserted
# success: Measurement 259 inserted
# success: Measurement 260 inserted
# success: Measurement 261 inserted
# success: Measurement 262 inserted
# success: Measurement 263 inserted
# success: Measurement 264 inserted
# success: Measurement 265 inserted
# success: Measurement 266 inserted
# success: Measurement 267 inserted
# success: Measurement 268 inserted
# success: Measurement 269 inserted
# success: Measurement 270 inserted
# success: Measurement 271 inserted
# success: Measurement 272 inserted
# success: Measurement 273 inserted
# success: Measurement 274 inserted
# success: Measurement 275 inserted
# success: Measurement 276 inserted
# success: Measurement 277 inserted
# success: Measurement 278 inserted
# success: Measurement 279 inserted
# success: Measurement 280 inserted
# success: Measurement 281 inserted
# success: Measurement 282 inserted
# success: Measurement 283 inserted
# success: Measurement 284 inserted
# success: Measurement 285 inserted
# success: Measurement 286 inserted
# success: Measurement 287 inserted
# success: Measurement 288 inserted
# success: Measurement 289 inserted
# success: Measurement 290 inserted
# success: Measurement 291 inserted
# success: Measurement 292 inserted
# success: Measurement 293 inserted
# success: Measurement 294 inserted
# success: Measurement 295 inserted
# success: Measurement 296 inserted
# success: Measurement 297 inserted
# success: Measurement 298 inserted
# success: Measurement 299 inserted
# success: Measurement 300 inserted
# success: Measurement 301 inserted
# success: Measurement 302 inserted
# success: Measurement 303 inserted
# success: Measurement 304 inserted
# success: Measurement 305 inserted
# success: Measurement 306 inserted
# success: Measurement 307 inserted
# success: Measurement 308 inserted
# success: Measurement 309 inserted
# success: Measurement 310 inserted
# success: Measurement 311 inserted
# success: Measurement 312 inserted
# success: Measurement 313 inserted
# success: Measurement 314 inserted
# success: Measurement 315 inserted
# success: Measurement 316 inserted
# success: Measurement 317 inserted
# success: Measurement 318 inserted
# success: Measurement 319 inserted
# success: Measurement 320 inserted
# success: Measurement 321 inserted
# success: Measurement 322 inserted
# success: Measurement 323 inserted
# success: Measurement 324 inserted
# success: Measurement 325 inserted
# success: Measurement 326 inserted
# success: Measurement 327 inserted
# success: Measurement 328 inserted
# success: Measurement 329 inserted
# success: Measurement 330 inserted
# success: Measurement 331 inserted
# success: Measurement 332 inserted
# success: Measurement 333 inserted
# success: Measurement 334 inserted
# success: Measurement 335 inserted
# success: Measurement 336 inserted
# success: Measurement 337 inserted
# success: Measurement 338 inserted
# success: Measurement 339 inserted
# success: Measurement 340 inserted
# success: Measurement 341 inserted
# success: Measurement 342 inserted
# success: Measurement 343 inserted
# success: Measurement 344 inserted
# success: Measurement 345 inserted
# success: Measurement 346 inserted
# success: Measurement 347 inserted
# success: Measurement 348 inserted
# success: Measurement 349 inserted
# success: Measurement 350 inserted
# success: Measurement 351 inserted
# success: Measurement 352 inserted
# success: Measurement 353 inserted
# success: Measurement 354 inserted
# success: Measurement 355 inserted
# success: Measurement 356 inserted
# success: Measurement 357 inserted
# success: Measurement 358 inserted
# success: Measurement 359 inserted
# success: Measurement 360 inserted
# success: Measurement 361 inserted
# success: Measurement 362 inserted
# success: Measurement 363 inserted
# success: Measurement 364 inserted
# success: Measurement 365 inserted
# success: Measurement 366 inserted
# success: Measurement 367 inserted
# success: Measurement 368 inserted
# success: Measurement 369 inserted
# success: Measurement 370 inserted
# success: Measurement 371 inserted
# success: Measurement 372 inserted
# success: Measurement 373 inserted
# success: Measurement 374 inserted
# success: Measurement 375 inserted
# success: Measurement 376 inserted
# success: Measurement 377 inserted
# success: Measurement 378 inserted
# success: Measurement 379 inserted
# success: Measurement 380 inserted
# success: Measurement 381 inserted
# success: Measurement 382 inserted
# success: Measurement 383 inserted
# success: Measurement 384 inserted
# success: Measurement 385 inserted
# success: Measurement 386 inserted
# success: Measurement 387 inserted
# success: Measurement 388 inserted
# success: Measurement 389 inserted
# success: Measurement 390 inserted
# success: Measurement 391 inserted
# success: Measurement 392 inserted
# success: Measurement 393 inserted
# success: Measurement 394 inserted
# success: Measurement 395 inserted
# success: Measurement 396 inserted
# success: Measurement 397 inserted
# success: Measurement 398 inserted
# success: Measurement 399 inserted
# success: Measurement 400 inserted
# success: Measurement 401 inserted
# success: Measurement 402 inserted
# success: Measurement 403 inserted
# success: Measurement 404 inserted
# success: Measurement 405 inserted
# success: Measurement 406 inserted
# success: Measurement 407 inserted
# success: Measurement 408 inserted
# success: Measurement 409 inserted
# success: Measurement 410 inserted
# success: Measurement 411 inserted
# success: Measurement 412 inserted
# success: Measurement 413 inserted
# success: Measurement 414 inserted
# success: Measurement 415 inserted
# success: Measurement 416 inserted
# success: Measurement 417 inserted
# success: Measurement 418 inserted
# success: Measurement 419 inserted
# success: Measurement 420 inserted
# success: Measurement 421 inserted
# success: Measurement 422 inserted
# success: Measurement 423 inserted
# success: Measurement 424 inserted
# success: Measurement 425 inserted
# success: Measurement 426 inserted
# success: Measurement 427 inserted
# success: Measurement 428 inserted
# success: Measurement 429 inserted
# success: Measurement 430 inserted
# success: Measurement 431 inserted
# success: Measurement 432 inserted
# success: Measurement 433 inserted
# success: Measurement 434 inserted
# success: Measurement 435 inserted
# success: Measurement 436 inserted
# success: Measurement 437 inserted
# success: Measurement 438 inserted
# success: Measurement 439 inserted
# success: Measurement 440 inserted
# success: Measurement 441 inserted
# success: Measurement 442 inserted
# success: Measurement 443 inserted
# success: Measurement 444 inserted
# success: Measurement 445 inserted
# success: Measurement 446 inserted
# success: Measurement 447 inserted
# success: Measurement 448 inserted
# success: Measurement 449 inserted
# success: Measurement 450 inserted
# success: Measurement 451 inserted
# success: Measurement 452 inserted
# success: Measurement 453 inserted
# success: Measurement 454 inserted
# success: Measurement 455 inserted
# success: Measurement 456 inserted
# success: Measurement 457 inserted
# success: Measurement 458 inserted
# success: Measurement 459 inserted
# success: Measurement 460 inserted
# success: Measurement 461 inserted
# success: Measurement 462 inserted
# success: Measurement 463 inserted
# success: Measurement 464 inserted
# success: Measurement 465 inserted
# success: Measurement 466 inserted
# success: Measurement 467 inserted
# success: Measurement 468 inserted
# success: Measurement 469 inserted
# success: Measurement 470 inserted
# success: Measurement 471 inserted
# success: Measurement 472 inserted
# success: Measurement 473 inserted
# success: Measurement 474 inserted
# success: Measurement 475 inserted
# success: Measurement 476 inserted
# success: Measurement 477 inserted
# success: Measurement 478 inserted
# success: Measurement 479 inserted
# success: Measurement 480 inserted
# success: Measurement 481 inserted
# success: Measurement 482 inserted
# success: Measurement 483 inserted
# success: Measurement 484 inserted
# success: Measurement 485 inserted
# success: Measurement 486 inserted
# success: Measurement 487 inserted
# success: Measurement 488 inserted
# success: Measurement 489 inserted
# success: Measurement 490 inserted
# success: Measurement 491 inserted
# success: Measurement 492 inserted
# success: Measurement 493 inserted
# success: Measurement 494 inserted
# success: Measurement 495 inserted
# success: Measurement 496 inserted
# success: Measurement 497 inserted
# success: Measurement 498 inserted
# success: Measurement 499 inserted
# success: Measurement 500 inserted
# success: Measurement 501 inserted
# success: Measurement 502 inserted
# success: Measurement 503 inserted
# success: Measurement 504 inserted
# success: Measurement 505 inserted
# success: Measurement 506 inserted
# success: Measurement 507 inserted
# success: Measurement 508 inserted
# success: Measurement 509 inserted
# success: Measurement 510 inserted
# success: Measurement 511 inserted
# success: Measurement 512 inserted
# success: Measurement 513 inserted
# success: Measurement 514 inserted
# success: Measurement 515 inserted
# success: Measurement 516 inserted
# success: Measurement 517 inserted
# success: Measurement 518 inserted
# success: Measurement 519 inserted
# success: Measurement 520 inserted
# success: Measurement 521 inserted
# success: Measurement 522 inserted
# success: Measurement 523 inserted
# success: Measurement 524 inserted
# success: Measurement 525 inserted
# success: Measurement 526 inserted
# success: Measurement 527 inserted
# success: Measurement 528 inserted
# success: Measurement 529 inserted
# success: Measurement 530 inserted
# success: Measurement 531 inserted
# success: Measurement 532 inserted
# success: Measurement 533 inserted
# success: Measurement 534 inserted
# success: Measurement 535 inserted
# success: Measurement 536 inserted
# success: Measurement 537 inserted
# success: Measurement 538 inserted
# success: Measurement 539 inserted
# success: Measurement 540 inserted
# success: Measurement 541 inserted
# success: Measurement 542 inserted
# success: Measurement 543 inserted
# success: Measurement 544 inserted
# success: Measurement 545 inserted
# success: Measurement 546 inserted
# success: Measurement 547 inserted
# success: Measurement 548 inserted
# success: Measurement 549 inserted
# success: Measurement 550 inserted
# success: Measurement 551 inserted
# success: Measurement 552 inserted
# success: Measurement 553 inserted
# success: Measurement 554 inserted
# success: Measurement 555 inserted
# success: Measurement 556 inserted
# success: Measurement 557 inserted
# success: Measurement 558 inserted
# success: Measurement 559 inserted
# success: Measurement 560 inserted
# success: Measurement 561 inserted
# success: Measurement 562 inserted
# success: Measurement 563 inserted
# success: Measurement 564 inserted
# success: Measurement 565 inserted
# success: Measurement 566 inserted
# success: Measurement 567 inserted
# success: Measurement 568 inserted
# success: Measurement 569 inserted
# success: Measurement 570 inserted
# success: Measurement 571 inserted
# success: Measurement 572 inserted
# success: Measurement 573 inserted
# success: Measurement 574 inserted
# success: Measurement 575 inserted
# success: Measurement 576 inserted
# success: Measurement 577 inserted
# success: Measurement 578 inserted
# success: Measurement 579 inserted
# success: Measurement 580 inserted
# success: Measurement 581 inserted
# success: Measurement 582 inserted
# success: Measurement 583 inserted
# success: Measurement 584 inserted
# success: Measurement 585 inserted
# success: Measurement 586 inserted
# success: Measurement 587 inserted
# success: Measurement 588 inserted
# success: Measurement 589 inserted
# success: Measurement 590 inserted
# success: Measurement 591 inserted
# success: Measurement 592 inserted
# success: Measurement 593 inserted
# success: Measurement 594 inserted
# success: Measurement 595 inserted
# success: Measurement 596 inserted
# success: Measurement 597 inserted
# success: Measurement 598 inserted
# success: Measurement 599 inserted
# success: Measurement 600 inserted
# success: Measurement 601 inserted
# success: Measurement 602 inserted
# success: Measurement 603 inserted
# success: Measurement 604 inserted
# success: Measurement 605 inserted
# success: Measurement 606 inserted
# success: Measurement 607 inserted
# success: Measurement 608 inserted
# success: Measurement 609 inserted
# success: Measurement 610 inserted
# success: Measurement 611 inserted
# success: Measurement 612 inserted
# success: Measurement 613 inserted
# success: Measurement 614 inserted
# success: Measurement 615 inserted
# success: Measurement 616 inserted
# success: Measurement 617 inserted
# success: Measurement 618 inserted
# success: Measurement 619 inserted
# success: Measurement 620 inserted
# success: Measurement 621 inserted
# success: Measurement 622 inserted
# success: Measurement 623 inserted
# success: Measurement 624 inserted
# success: Measurement 625 inserted
# success: Measurement 626 inserted
# success: Measurement 627 inserted
# success: Measurement 628 inserted
# success: Measurement 629 inserted
# success: Measurement 630 inserted
# success: Measurement 631 inserted
# success: Measurement 632 inserted
# success: Measurement 633 inserted
# success: Measurement 634 inserted
# success: Measurement 635 inserted
# success: Measurement 636 inserted
# success: Measurement 637 inserted
# success: Measurement 638 inserted
# success: Measurement 639 inserted
# success: Measurement 640 inserted
# success: Measurement 641 inserted
# success: Measurement 642 inserted
# success: Measurement 643 inserted
# success: Measurement 644 inserted
# success: Measurement 645 inserted
# success: Measurement 646 inserted
# success: Measurement 647 inserted
# success: Measurement 648 inserted
# success: Measurement 649 inserted
# success: Measurement 650 inserted
# success: Measurement 651 inserted
# success: Measurement 652 inserted
# success: Measurement 653 inserted
# success: Measurement 654 inserted
# success: Measurement 655 inserted
# success: Measurement 656 inserted
# success: Measurement 657 inserted
# success: Measurement 658 inserted
# success: Measurement 659 inserted
# success: Measurement 660 inserted
# success: Measurement 661 inserted
# success: Measurement 662 inserted
# success: Measurement 663 inserted
# success: Measurement 664 inserted
# success: Measurement 665 inserted
# success: Measurement 666 inserted
# success: Measurement 667 inserted
# success: Measurement 668 inserted
# success: Measurement 669 inserted
# success: Measurement 670 inserted
# success: Measurement 671 inserted
# success: Measurement 672 inserted
# success: Measurement 673 inserted
# success: Measurement 674 inserted
# success: Measurement 675 inserted
# success: Measurement 676 inserted
# success: Measurement 677 inserted
# success: Measurement 678 inserted
# success: Measurement 679 inserted
# success: Measurement 680 inserted
# success: Measurement 681 inserted
# success: Measurement 682 inserted
# success: Measurement 683 inserted
# success: Measurement 684 inserted
# success: Measurement 685 inserted
# success: Measurement 686 inserted
# success: Measurement 687 inserted
# success: Measurement 688 inserted
# success: Measurement 689 inserted
# success: Measurement 690 inserted
# success: Measurement 691 inserted
# success: Measurement 692 inserted
# success: Measurement 693 inserted
# success: Measurement 694 inserted
# success: Measurement 695 inserted
# success: Measurement 696 inserted
# success: Measurement 697 inserted
# success: Measurement 698 inserted
# success: Measurement 699 inserted
# success: Measurement 700 inserted
# success: Measurement 701 inserted
# success: Measurement 702 inserted
# success: Measurement 703 inserted
# success: Measurement 704 inserted
# success: Measurement 705 inserted
# success: Measurement 706 inserted
# success: Measurement 707 inserted
# success: Measurement 708 inserted
# success: Measurement 709 inserted
# success: Measurement 710 inserted
# success: Measurement 711 inserted
# success: Measurement 712 inserted
# success: Measurement 713 inserted
# success: Measurement 714 inserted
# success: Measurement 715 inserted
# success: Measurement 716 inserted
# success: Measurement 717 inserted
# success: Measurement 718 inserted
# success: Measurement 719 inserted
# success: Measurement 720 inserted
# success: Measurement 721 inserted
# success: Measurement 722 inserted
# success: Measurement 723 inserted
# success: Measurement 724 inserted
# success: Measurement 725 inserted
# success: Measurement 726 inserted
# success: Measurement 727 inserted
# success: Measurement 728 inserted
# success: Measurement 729 inserted
# success: Measurement 730 inserted
# success: Measurement 731 inserted
# success: Measurement 732 inserted
# success: Measurement 733 inserted
# success: Measurement 734 inserted
# success: Measurement 735 inserted
# success: Measurement 736 inserted
# success: Measurement 737 inserted
# success: Measurement 738 inserted
# success: Measurement 739 inserted
# success: Measurement 740 inserted
# success: Measurement 741 inserted
# success: Measurement 742 inserted
# success: Measurement 743 inserted
# success: Measurement 744 inserted
# success: Measurement 745 inserted
# success: Measurement 746 inserted
# success: Measurement 747 inserted
# success: Measurement 748 inserted
# success: Measurement 749 inserted
# success: Measurement 750 inserted
# success: Measurement 751 inserted
# success: Measurement 752 inserted
# success: Measurement 753 inserted
# success: Measurement 754 inserted
# success: Measurement 755 inserted
# success: Measurement 756 inserted
# success: Measurement 757 inserted
# success: Measurement 758 inserted
# success: Measurement 759 inserted
# success: Measurement 760 inserted
# success: Measurement 761 inserted
# success: Measurement 762 inserted
# success: Measurement 763 inserted
# success: Measurement 764 inserted
# success: Measurement 765 inserted
# success: Measurement 766 inserted
# success: Measurement 767 inserted
# success: Measurement 768 inserted
# success: Measurement 769 inserted
# success: Measurement 770 inserted
# success: Measurement 771 inserted
# success: Measurement 772 inserted
# success: Measurement 773 inserted
# success: Measurement 774 inserted
# success: Measurement 775 inserted
# success: Measurement 776 inserted
# success: Measurement 777 inserted
# success: Measurement 778 inserted
# success: Measurement 779 inserted
# success: Measurement 780 inserted
# success: Measurement 781 inserted
# success: Measurement 782 inserted
# success: Measurement 783 inserted
# success: Measurement 784 inserted
# success: Measurement 785 inserted
# success: Measurement 786 inserted
# success: Measurement 787 inserted
# success: Measurement 788 inserted
# success: Measurement 789 inserted
# success: Measurement 790 inserted
# success: Measurement 791 inserted
# success: Measurement 792 inserted
# success: Measurement 793 inserted
# success: Measurement 794 inserted
# success: Measurement 795 inserted
# success: Measurement 796 inserted
# success: Measurement 797 inserted
# success: Measurement 798 inserted
# success: Measurement 799 inserted
# success: Measurement 800 inserted
# success: Measurement 801 inserted
# success: Measurement 802 inserted
# success: Measurement 803 inserted
# success: Measurement 804 inserted
# success: Measurement 805 inserted
# success: Measurement 806 inserted
# success: Measurement 807 inserted
# success: Measurement 808 inserted
# success: Measurement 809 inserted
# success: Measurement 810 inserted
# success: Measurement 811 inserted
# success: Measurement 812 inserted
# success: Measurement 813 inserted
# success: Measurement 814 inserted
# success: Measurement 815 inserted
# success: Measurement 816 inserted
# success: Measurement 817 inserted
# success: Measurement 818 inserted
# success: Measurement 819 inserted
# success: Measurement 820 inserted
# success: Measurement 821 inserted
# success: Measurement 822 inserted
# success: Measurement 823 inserted
# success: Measurement 824 inserted
# success: Measurement 825 inserted
# success: Measurement 826 inserted
# success: Measurement 827 inserted
# success: Measurement 828 inserted
# success: Measurement 829 inserted
# success: Measurement 830 inserted
# success: Measurement 831 inserted
# success: Measurement 832 inserted
# success: Measurement 833 inserted
# success: Measurement 834 inserted
# success: Measurement 835 inserted
# success: Measurement 836 inserted
# success: Measurement 837 inserted
# success: Measurement 838 inserted
# success: Measurement 839 inserted
# success: Measurement 840 inserted
# success: Measurement 841 inserted
# success: Measurement 842 inserted
# success: Measurement 843 inserted
# success: Measurement 844 inserted
# success: Measurement 845 inserted
# success: Measurement 846 inserted
# success: Measurement 847 inserted
# success: Measurement 848 inserted
# success: Measurement 849 inserted
# success: Measurement 850 inserted
# success: Measurement 851 inserted
# success: Measurement 852 inserted
# success: Measurement 853 inserted
# success: Measurement 854 inserted
# success: Measurement 855 inserted
# success: Measurement 856 inserted
# success: Measurement 857 inserted
# success: Measurement 858 inserted
# success: Measurement 859 inserted
# success: Measurement 860 inserted
# success: Measurement 861 inserted
# success: Measurement 862 inserted
# success: Measurement 863 inserted
# success: Measurement 864 inserted
# success: Measurement 865 inserted
# success: Measurement 866 inserted
# success: Measurement 867 inserted
# success: Measurement 868 inserted
# success: Measurement 869 inserted
# success: Measurement 870 inserted
# success: Measurement 871 inserted
# success: Measurement 872 inserted
# success: Measurement 873 inserted
# success: Measurement 874 inserted
# success: Measurement 875 inserted
# success: Measurement 876 inserted
# success: Measurement 877 inserted
# success: Measurement 878 inserted
# success: Measurement 879 inserted
# success: Measurement 880 inserted
# success: Measurement 881 inserted
# success: Measurement 882 inserted
# success: Measurement 883 inserted
# success: Measurement 884 inserted
# success: Measurement 885 inserted
# success: Measurement 886 inserted
# success: Measurement 887 inserted
# success: Measurement 888 inserted
# success: Measurement 889 inserted
# success: Measurement 890 inserted
# success: Measurement 891 inserted
# success: Measurement 892 inserted
# success: Measurement 893 inserted
# success: Measurement 894 inserted
# success: Measurement 895 inserted
# success: Measurement 896 inserted
# success: Measurement 897 inserted
# success: Measurement 898 inserted
# success: Measurement 899 inserted
# success: Measurement 900 inserted
# success: Measurement 901 inserted
# success: Measurement 902 inserted
# success: Measurement 903 inserted
# success: Measurement 904 inserted
# success: Measurement 905 inserted
# success: Measurement 906 inserted
# success: Measurement 907 inserted
# success: Measurement 908 inserted
# success: Measurement 909 inserted
# success: Measurement 910 inserted
# success: Measurement 911 inserted
# success: Measurement 912 inserted
# success: Measurement 913 inserted
# success: Measurement 914 inserted
# success: Measurement 915 inserted
# success: Measurement 916 inserted
# success: Measurement 917 inserted
# success: Measurement 918 inserted
# success: Measurement 919 inserted
# success: Measurement 920 inserted
# success: Measurement 921 inserted
# success: Measurement 922 inserted
# success: Measurement 923 inserted
# success: Measurement 924 inserted
# success: Measurement 925 inserted
# success: Measurement 926 inserted
# success: Measurement 927 inserted
# success: Measurement 928 inserted
# success: Measurement 929 inserted
# success: Measurement 930 inserted
# success: Measurement 931 inserted
# success: Measurement 932 inserted
# success: Measurement 933 inserted
# success: Measurement 934 inserted
# success: Measurement 935 inserted
# success: Measurement 936 inserted
# success: Measurement 937 inserted
# success: Measurement 938 inserted
# success: Measurement 939 inserted
# success: Measurement 940 inserted
# success: Measurement 941 inserted
# success: Measurement 942 inserted
# success: Measurement 943 inserted
# success: Measurement 944 inserted
# success: Measurement 945 inserted
# success: Measurement 946 inserted
# success: Measurement 947 inserted
# success: Measurement 948 inserted
# success: Measurement 949 inserted
# success: Measurement 950 inserted
# success: Measurement 951 inserted
# success: Measurement 952 inserted
# success: Measurement 953 inserted
# success: Measurement 954 inserted
# success: Measurement 955 inserted
# success: Measurement 956 inserted
# success: Measurement 957 inserted
# success: Measurement 958 inserted
# success: Measurement 959 inserted
# success: Measurement 960 inserted
# success: Measurement 961 inserted
# success: Measurement 962 inserted
# success: Measurement 963 inserted
# success: Measurement 964 inserted
# success: Measurement 965 inserted
# success: Measurement 966 inserted
# success: Measurement 967 inserted
# success: Measurement 968 inserted
# success: Measurement 969 inserted
# success: Measurement 970 inserted
# success: Measurement 971 inserted
# success: Measurement 972 inserted
# success: Measurement 973 inserted
# success: Measurement 974 inserted
# success: Measurement 975 inserted
# success: Measurement 976 inserted
# success: Measurement 977 inserted
# success: Measurement 978 inserted
# success: Measurement 979 inserted
# success: Measurement 980 inserted
# success: Measurement 981 inserted
# success: Measurement 982 inserted
# success: Measurement 983 inserted
# success: Measurement 984 inserted
# success: Measurement 985 inserted
# success: Measurement 986 inserted
# success: Measurement 987 inserted
# success: Measurement 988 inserted
# success: Measurement 989 inserted
# success: Measurement 990 inserted
# success: Measurement 991 inserted
# success: Measurement 992 inserted
# success: Measurement 993 inserted
# success: Measurement 994 inserted
# success: Measurement 995 inserted
# success: Measurement 996 inserted
# success: Measurement 997 inserted
# success: Measurement 998 inserted
# success: Measurement 999 inserted
# success: Measurement 1000 inserted
# success: Measurement 1001 inserted
# success: Measurement 1002 inserted
# success: Measurement 1003 inserted
# success: Measurement 1004 inserted
# success: Measurement 1005 inserted
# success: Measurement 1006 inserted
# success: Measurement 1007 inserted
# success: Measurement 1008 inserted
# success: Measurement 1009 inserted
# success: Measurement 1010 inserted
# success: Measurement 1011 inserted
# success: Measurement 1012 inserted
# success: Measurement 1013 inserted
# success: Measurement 1014 inserted
# success: Measurement 1015 inserted
# success: Measurement 1016 inserted
# success: Measurement 1017 inserted
# success: Measurement 1018 inserted
# success: Measurement 1019 inserted
# success: Measurement 1020 inserted
# success: Measurement 1726 inserted
# success: Measurement 1727 inserted
# success: Measurement 1728 inserted
# success: Measurement 1729 inserted
# success: Measurement 1730 inserted
# success: Measurement 1731 inserted
# success: Measurement 1732 inserted
# success: Measurement 1733 inserted
# success: Measurement 1734 inserted
# success: Measurement 1735 inserted
# success: Measurement 1736 inserted
# success: Measurement 1737 inserted
# success: Measurement 1738 inserted
# success: Measurement 1739 inserted
# success: Measurement 1740 inserted
# success: Measurement 1741 inserted
# success: Measurement 1742 inserted
# success: Measurement 1743 inserted
# success: Measurement 1744 inserted
# success: Measurement 1745 inserted
# success: Measurement 1746 inserted
# success: Measurement 1747 inserted
# success: Measurement 1748 inserted
# success: Measurement 1749 inserted
# success: Measurement 1750 inserted
# success: Measurement 1751 inserted
# success: Measurement 1752 inserted
# success: Measurement 1753 inserted
# success: Measurement 1754 inserted
# success: Measurement 1755 inserted
# success: Measurement 1756 inserted
# success: Measurement 1757 inserted
# success: Measurement 1758 inserted
# success: Measurement 1759 inserted
# success: Measurement 1760 inserted
# success: Measurement 1761 inserted
# success: Measurement 1762 inserted
# success: Measurement 1763 inserted
# success: Measurement 1764 inserted
# success: Measurement 1765 inserted
# success: Measurement 1766 inserted
# success: Measurement 1767 inserted
# success: Measurement 1768 inserted
# success: Measurement 1769 inserted
# success: Measurement 1770 inserted
# success: Measurement 1771 inserted
# success: Measurement 1772 inserted
# success: Measurement 1773 inserted
# success: Measurement 1774 inserted
# success: Measurement 1775 inserted
# success: Measurement 1776 inserted
# success: Measurement 1777 inserted
# success: Measurement 1778 inserted
# success: Measurement 1779 inserted
# success: Measurement 1780 inserted
# success: Measurement 1781 inserted
# success: Measurement 1782 inserted
# success: Measurement 1783 inserted
# success: Measurement 1784 inserted
# success: Measurement 1785 inserted
# success: Measurement 1786 inserted
# success: Measurement 1787 inserted
# success: Measurement 1788 inserted
# success: Measurement 1789 inserted
# success: Measurement 1790 inserted
# success: Measurement 1791 inserted
# success: Measurement 1792 inserted
# success: Measurement 1793 inserted

# %% [markdown]
# ## Your Task: Data Storage in PostgreSQL
# Following the above pattern, make sure all the   tables of our water schema are loaded with the data from the different CSV files.

# %%
# TODO: replace the content of this cell with your Python + SQL solution
# raise NotImplementedError

conn = pgconnect()
    
# check content of Organisations table
query_stmt = "SELECT COUNT(*) FROM Organisation"
print(query_stmt)
pgquery (conn, query_stmt, None)

# check content of Station table
query_stmt = "SELECT count(*) FROM Station"
print(query_stmt)
pgquery (conn, query_stmt, None)

# check content of Sensor table
query_stmt = "SELECT count(*) FROM Sensor"
print(query_stmt)
pgquery (conn, query_stmt, None)

# check content of Measurement table
query_stmt = "SELECT count(*) FROM Measurement"
print(query_stmt)
pgquery (conn, query_stmt, None)

conn.close()
# Out:
# connected
# SELECT COUNT(*) FROM Organisation
# (9,)
# SELECT count(*) FROM Station
# (9,)
# SELECT count(*) FROM Sensor
# (7,)
# SELECT count(*) FROM Measurement
# (1793,)

# %% [markdown]
# # End of Tutorial. Many Thanks.
