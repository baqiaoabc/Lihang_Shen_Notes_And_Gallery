# %%
# COMP5339 Week 5 Tutorial
# Material last updated: 23 March 2025
# Note materials were designed with the Roboto Condensed font, which can be installed here: https://www.1001fonts.com/roboto-condensed-font.html

from IPython.display import HTML
HTML('''
    <style> body {font-family: "Roboto Condensed Light", "Roboto Condensed";} h2 {padding: 10px 12px; background-color: #E64626; position: static; color: #ffffff; font-size: 40px;} .text_cell_render p { font-size: 15px; } .text_cell_render h1 { font-size: 30px; } h1 {padding: 10px 12px; background-color: #E64626; color: #ffffff; font-size: 40px;} .text_cell_render h3 { padding: 10px 12px; background-color: #0148A4; position: static; color: #ffffff; font-size: 20px;} h4:before{ 
    content: "@"; font-family:"Wingdings"; font-style:regular; margin-right: 4px;} .text_cell_render h4 {padding: 8px; font-family: "Roboto Condensed Light"; position: static; font-style: italic; background-color: #FFB800; color: #ffffff; font-size: 18px; text-align: center; border-radius: 5px;}input[type=submit] {background-color: #E64626; border: solid; border-color: #734036; color: white; padding: 8px 16px; text-decoration: none; margin: 4px 2px; cursor: pointer; border-radius: 20px;}</style>
    <script> code_show=true; function code_toggle() {if (code_show){$('div.input').hide();} else {$('div.input').show();} code_show = !code_show} $( document ).ready(code_toggle);</script>
    <form action="javascript:code_toggle()"><input type="submit" value="Hide/show all code."></form>
''')
# Out:
#     <style> body {font-family: "Roboto Condensed Light", "Roboto Condensed";} h2 {padding: 10px 12px; background-color: #E64626; position: static; color: #ffffff; font-size: 40px;} .text_cell_render p { font-size: 15px; } .text_cell_render h1 { font-size: 30px; } h1 {padding: 10px 12px; background-color: #E64626; color: #ffffff; font-size: 40px;} .text_cell_render h3 { padding: 10px 12px; background-color: #0148A4; position: static; color: #ffffff; font-size: 20px;} h4:before{
#     content: "@"; font-family:"Wingdings"; font-style:regular; margin-right: 4px;} .text_cell_render h4 {padding: 8px; font-family: "Roboto Condensed Light"; position: static; font-style: italic; background-color: #FFB800; color: #ffffff; font-size: 18px; text-align: center; border-radius: 5px;}input[type=submit] {background-color: #E64626; border: solid; border-color: #734036; color: white; padding: 8px 16px; text-decoration: none; margin: 4px 2px; cursor: pointer; border-radius: 20px;}</style>
#     <script> code_show=true; function code_toggle() {if (code_show){$('div.input').hide();} else {$('div.input').show();} code_show = !code_show} $( document ).ready(code_toggle);</script>
#     <form action="javascript:code_toggle()"><input type="submit" value="Hide/show all code."></form>

# %% [markdown]
# # Week 5 - Web APIs: Working with semi-structured data

# %% [markdown]
# This week will be going beyond scraping data from websites and using APIs to help collect data efficiently. Web APIs are specifically provided to give access to data through programs. The advantages are that the data is well defined and consistent, with a predefined set of operations.
#
# This tutorial will give you a taste on the potential that APIs offer and hopefully opens your mind to the possibilities of data integrations in your future projects.
#
# This will require the following Python libraries:
# - **Request**         for interacting with websites and web services
# - **Pandas**          for dataframe management

# %% [markdown]
# ## 1. Web APIs

# %% [markdown]
# We'll explore a few fun examples of APIs with a variety of data types. These libraries will help us process JSON data types, and even to display images.

# %% [markdown]
# ### 1.1 Exploring JSON Objects with APIs

# %% [markdown]
# The World Bank provides the following web API which gives the total population in a Country in a specific year. More information about the API can be found in their [Developer Information
# ](https://datahelpdesk.worldbank.org/knowledgebase/topics/125589-developer-information).

# %%
import requests

year = '2022'

response = requests.get(f"https://api.worldbank.org/v2/country/aus/indicator/SP.POP.TOTL?date={year}&format=json")

response
# Out:
# <Response [200]>

# %% [markdown]
# Simply returning the response yields nothing of particular use, just the HTTP status code of our request (you should get [200](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes), which indicates success).
#
# To interpret its full body of returned information as a JSON object, we can use the `.json()` function:

# %%
response.json()
# Out:
# [{'page': 1,
#   'pages': 1,
#   'per_page': 50,
#   'total': 1,
#   'sourceid': '2',
#   'lastupdated': '2025-01-28'},
#  [{'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'AU', 'value': 'Australia'},
#    'countryiso3code': 'AUS',
#    'date': '2022',
#    'value': 26014399,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0}]]

# %% [markdown]
# The **json** library can also be leveraged to display the information in a nicer way. ``json.dumps()`` takes a JSON object and turns it into a string, while ``json.loads()`` can parse a valid string into a JSON object. The example below takes our response, formats it nicely, and sorts the keys alphabetically:

# %%
import json
print(json.dumps(response.json(), indent=4, sort_keys=True))
# Out:
# [
#     {
#         "lastupdated": "2025-01-28",
#         "page": 1,
#         "pages": 1,
#         "per_page": 50,
#         "sourceid": "2",
#         "total": 1
#     },
#     [
#         {
#             "country": {
#                 "id": "AU",
#                 "value": "Australia"
#             },
#             "countryiso3code": "AUS",
#             "date": "2022",
#             "decimal": 0,
#             "indicator": {
#                 "id": "SP.POP.TOTL",
#                 "value": "Population, total"
#             },
#             "obs_status": "",
#             "unit": "",
#             "value": 26014399
#         }
#     ]
# ]

# %% [markdown]
# In this case, the JSON object returned is list of dictionaries. We can access individual elements by index and name:

# %%
population = response.json()[1][0]['value']
print("Population of Australia in year", year, "is", population)
# Out:
# Population of Australia in year 2022 is 26014399

# %% [markdown]
# ### 1.2 Exploring Images with APIs

# %% [markdown]
# We can even query the web to extract images, rather than a JSON object. The below helper function will process an image as a JPG with fixed dimensions:

# %%
import ipywidgets as widgets
def display_image(response, w=200, h=300):
    return widgets.Image(value=response.content, format='jpg', width=w, height=h)

# %% [markdown]
# Take the simple PlaceDog website, which returns a randomised image of dogs for a given dimension ratio (in our case, just 300x200)

# %%
response = requests.get('https://place.dog/300/200')
display_image(response)
# Out:
# Image(value=b'\xff\xd8\xff\xdb\x00C\x00\x06\x04\x05\x06\x05\x04\x06\x06\x05\x06\x07\x07\x06\x08\n\x10\n\n\t\t\…

# %% [markdown]
# ### 1.3 Using API Documentation

# %% [markdown]
# Most APIs will have more functionality and require you to read their documentation to understand what other features can be extracted. Let's try a dog API with slightly more sophisticated documentation that allows us to extract both information and images - the [Stanford Dogs Dataset](https://dog.ceo/dog-api/documentation/).

# %%
response = requests.get('https://dog.ceo/api/breed/labrador/images/random')
breeds = response.json()
breeds.keys()
# Out:
# dict_keys(['message', 'status'])

# %% [markdown]
# As seen by observing the keys above, or consulting the documentation, two things are returned - a "message", and the "status". We're interested in the "message":

# %%
breeds['message']
# Out:
# 'https://images.dog.ceo/breeds/labrador/n02099712_7749.jpg'

# %% [markdown]
# The "[breed](https://dog.ceo/dog-api/documentation/breed)" page of the documentation defines the general format of a URL to return a random image of a selected dog breed. The function below leverages this to return a single image from the selected breed:

# %%
def random_dog(breed):
    # This command returns a URL to a random image of the selected dog breed.
    # We would need to do another call of requests.get() to get the actual image.
    response = requests.get(f'https://dog.ceo/api/breed/{breed}/images/random')
    breed = response.json()['message']
    response_image = requests.get(breed)
    return display_image(response_image)

# %% [markdown]
# Try choosing a breed from the JSON above, and returning an image for it below (currently returns a 'husky'):

# %%
random_dog('husky')
# Out:
# Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x08\x06\x0…

# %% [markdown]
# ### 1.4 Using DataFrames with APIs

# %% [markdown]
# Take another animal-related example of an API below, with the [**TheCatAPI**](https://developers.thecatapi.com/), where users can request animal data in JSON format.

# %%
import pandas as pd
response = requests.get('https://api.thecatapi.com/v1/images/search')
print(response.status_code)
animal_info = response.json()
animal_info
# Out:
# 200
# [{'id': 'MTg1NDIwNQ',
#   'url': 'https://cdn2.thecatapi.com/images/MTg1NDIwNQ.jpg',
#   'width': 685,
#   'height': 1024}]

# %% [markdown]
# **Task: Return the random entries of 10 animals from the API as a dataframe.**
#
# Investigate the documentation, find the url to request so that the data of 10 animals can be extracted at once, and return this as a Pandas dataframe. Note that with dataframes, this will prove much trickier on less consistent data sources! JSON objects can contain vary greatly between objects with varying depths - it is much simpler here since each animal's object contains a single level of depth.

# %%
### TO DO
import pandas as pd
response = requests.get('https://api.thecatapi.com/v1/images/search?limit=10')
animal_info = pd.read_json(response.text)
animal_info
# Out:
#            id                                               url  width  height
# 0         14s         https://cdn2.thecatapi.com/images/14s.gif    500     220
# 1         2sc         https://cdn2.thecatapi.com/images/2sc.jpg   1600    1200
# 2         385         https://cdn2.thecatapi.com/images/385.jpg    400     600
# 3         5oj         https://cdn2.thecatapi.com/images/5oj.jpg    600     434
# 4         8tk         https://cdn2.thecatapi.com/images/8tk.jpg    960    1280
# 5         a9p         https://cdn2.thecatapi.com/images/a9p.jpg    510     383
# 6         at5         https://cdn2.thecatapi.com/images/at5.png    720     552
# 7  MTUwMDg4NQ  https://cdn2.thecatapi.com/images/MTUwMDg4NQ.jpg    500     333
# 8  MTg1NTk4Mg  https://cdn2.thecatapi.com/images/MTg1NTk4Mg.jpg    500     331
# 9  MTk3MTcwNw  https://cdn2.thecatapi.com/images/MTk3MTcwNw.jpg    640     479

# %% [markdown]
# ## 2. Map APIs

# %% [markdown]
# Additionally to simply taking what is returned to us, we can specify parameters to send to a web service.
#
# There are several Map API systems that allow you to convert a location address to a GPS location (and some more information). The most popular of these is Google Maps API. However, this underwent an access change in June 2018 which meant that it now requires an API key and associated billing information.
#
# Instead, we will use the Open Street Maps project at https://www.openstreetmap.org, particularly their `nominatim` data access API ([documentation here](https://nominatim.org/release-docs/develop/api/Search/)).
#
# **Note that this service does have however a restriction of 1 API call per second.**
#
# The helper function below will receive given parameters, and carry out the request, leaving it a few seconds first:

# %%
import time as t
def address_details(params, wait=5):
    base_url = 'https://nominatim.openstreetmap.org/search'
    headers = {'User-Agent': 'COMP5339'}
    t.sleep(wait)  # 5 second wait to avoid overloading (too many requests could look out the whole uni's IP range!)
    response = requests.get(base_url, params = params, headers = headers)
    return response.json()

# %% [markdown]
# The following example looks up the GPS location of building oppositing the School of CS building at "50 Cleveland Street, Chippendale, Australia":

# %%
parameters = {'q': '50 Cleveland Street, Chippendale, Australia', 'format': 'json', 'addressdetails': 0}
results = address_details(parameters)
print(json.dumps(results, indent=4))
# Out:
# [
#     {
#         "place_id": 19203128,
#         "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright",
#         "osm_type": "node",
#         "osm_id": 4127856495,
#         "lat": "-33.8879173",
#         "lon": "151.1949359",
#         "class": "place",
#         "type": "house",
#         "place_rank": 30,
#         "importance": 8.246051728079679e-05,
#         "addresstype": "place",
#         "name": "",
#         "display_name": "50, Cleveland Street, Chippendale, Sydney CBD, Sydney, Council of the City of Sydney, New South Wales, 2008, Australia",
#         "boundingbox": [
#             "-33.8879673",
#             "-33.8878673",
#             "151.1948859",
#             "151.1949859"
#         ]
#     }
# ]

# %% [markdown]
# If we were less specific about which suburb this "50 Cleveland Street" is in Australia, multiple results will be returned by the search:

# %%
parameters = {'q': '50 Cleveland Street, Australia', 'format': 'json', 'addressdetails': 1}
results = address_details(parameters)
print(json.dumps(results, indent=4))
# Out:
# [
#     {
#         "place_id": 19203128,
#         "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright",
#         "osm_type": "node",
#         "osm_id": 4127856495,
#         "lat": "-33.8879173",
#         "lon": "151.1949359",
#         "class": "place",
#         "type": "house",
#         "place_rank": 30,
#         "importance": 8.246051728079679e-05,
#         "addresstype": "place",
#         "name": "",
#         "display_name": "50, Cleveland Street, Chippendale, Sydney CBD, Sydney, Council of the City of Sydney, New South Wales, 2008, Australia",
#         "address": {
#             "house_number": "50",
#             "road": "Cleveland Street",
#             "suburb": "Chippendale",
#             "borough": "Sydney CBD",
#             "city": "Sydney",
#             "municipality": "Council of the City of Sydney",
#             "state": "New South Wales",
#             "ISO3166-2-lvl4": "AU-NSW",
#             "postcode": "2008",
#             "country": "Australia",
#             "country_code": "au"
#         },
#         "boundingbox": [
#             "-33.8879673",
#             "-33.8878673",
#             "151.1948859",
#             "151.1949859"
#         ]
#     },
#     {
#         "place_id": 23169133,
#         "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright",
#         "osm_type": "node",
#         "osm_id": 6351438673,
#         "lat": "-27.4999818",
#         "lon": "153.044542",
#         "class": "place",
#         "type": "house",
#         "place_rank": 30,
#         "importance": 7.694132906076169e-05,
#         "addresstype": "place",
#         "name": "",
#         "display_name": "50, Cleveland Street, Stones Corner, City of Brisbane, Queensland, 4120, Australia",
#         "address": {
#             "house_number": "50",
#             "road": "Cleveland Street",
#             "suburb": "Stones Corner",
#             "city_district": "Stones Corner",
#             "city": "City of Brisbane",
#             "state": "Queensland",
#             "ISO3166-2-lvl4": "AU-QLD",
#             "postcode": "4120",
#             "country": "Australia",
#             "country_code": "au"
#         },
#         "boundingbox": [
#             "-27.5000318",
#             "-27.4999318",
#             "153.0444920",
#             "153.0445920"
#         ]
#     },
#     {
#         "place_id": 28638396,
#         "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright",
#         "osm_type": "way",
#         "osm_id": 424520657,
#         "lat": "-31.90439355",
#         "lon": "115.87766334594444",
#         "class": "building",
#         "type": "detached",
#         "place_rank": 30,
#         "importance": 7.485389486529362e-05,
#         "addresstype": "building",
#         "name": "",
#         "display_name": "50, Cleveland Street, Dianella, City of Stirling, Western Australia, 6059, Australia",
#         "address": {
#             "house_number": "50",
#             "road": "Cleveland Street",
#             "suburb": "Dianella",
#             "municipality": "City of Stirling",
#             "state": "Western Australia",
#             "ISO3166-2-lvl4": "AU-WA",
#             "postcode": "6059",
#             "country": "Australia",
#             "country_code": "au"
#         },
#         "boundingbox": [
#             "-31.9045071",
#             "-31.9042817",
#             "115.8775241",
#             "115.8777910"
#         ]
#     }
# ]

# %% [markdown]
# Note in this case, an extra layer of depth is introduced for each search result - the address, which is itself a dictionary inside the main dictionary. We can "flatten" this into a dataframe using Pandas' `json_normalize()` function, which will return a dataframe with one row per search result:

# %%
pd.json_normalize(results)
# Out:
#    place_id                                            licence osm_type  \
# 0  19203128  Data © OpenStreetMap contributors, ODbL 1.0. h...     node
# 1  23169133  Data © OpenStreetMap contributors, ODbL 1.0. h...     node
# 2  28638396  Data © OpenStreetMap contributors, ODbL 1.0. h...      way
#
#        osm_id           lat                 lon     class      type  \
# 0  4127856495   -33.8879173         151.1949359     place     house
# 1  6351438673   -27.4999818          153.044542     place     house
# 2   424520657  -31.90439355  115.87766334594444  building  detached
#
#    place_rank  importance  ... address.suburb address.borough  \
# 0          30    0.000082  ...    Chippendale      Sydney CBD
# 1          30    0.000077  ...  Stones Corner             NaN
# 2          30    0.000075  ...       Dianella             NaN
#
#        address.city           address.municipality      address.state  \
# 0            Sydney  Council of the City of Sydney    New South Wales
# 1  City of Brisbane                            NaN         Queensland
# 2               NaN               City of Stirling  Western Australia
#
#   address.ISO3166-2-lvl4 address.postcode address.country  \
# 0                 AU-NSW             2008       Australia
# 1                 AU-QLD             4120       Australia
# 2                  AU-WA             6059       Australia
#
#   address.country_code address.city_district
# 0                   au                   NaN
# 1                   au         Stones Corner
# 2                   au                   NaN
#
# [3 rows x 26 columns]

# %% [markdown]
# **Task: Find the maximum road speed of a location of your choice using the API.**
#
# Select a location known to you (or take the definitely random example of [150 Freston Road, London](https://www.youtube.com/watch?v=j0FyxbiEgo0)), and try using the 'extratags' parameter (check the documentation) to determine the maximum speed of that road.

# %%
### TO DO
parameters = {'q': '150 Freston Road, London', 'format': 'json', 'addressdetails': 1, 'extratags': 1}
results = address_details(parameters)
# print(json.dumps(results, indent=4))
print("Maximum speed:", results[0]['extratags']['maxspeed'])
# Out:
# Maximum speed: 20 mph

# %% [markdown]
# ## 3. Extension (Optional)

# %% [markdown]
# As a data engineer, sometimes our responsibility is creating a data pipeline to extract information. The setup of these data pipelines is the most time consuming task and the entire data wrangling/cleaning phase of a data science product is  more than 80% of the time cost [(Breaking the 80/20 rule: How data catalogs transform data scientists’ productivity)](https://medium.com/@armand_ruiz/breaking-the-80-20-rule-how-data-catalogs-transform-data-scientists-productivity-7759a23a8893). We will have to wear many hats, which is why the extension task this week is using YouTube's Data API.
#
# The YouTube Data API will require a Google account and the creation of an API key to query data. Here are instructions on how to do that: https://developers.google.com/youtube/v3/getting-started
#
# **Note: Your default quota allocation is 10,000 units per day. This is 100 search queries a day!**
#
# Google calculates your quota usage by assigning a cost to each request. Different types of operations have different quota costs. For example:
#
# * read operation that retrieves a list of resources (channels, videos, playlists) usually costs 1 unit.
# * write operation that creates, updates, or deletes a resource usually has costs 50 units.
# * search request costs 100 units.
# * video upload costs 1600 units.
#
# After creating your API key, we will need to install a Python module:
# - Anaconda: `conda install -c conda-forge google-api-python-client`
# - or Pip: `pip install google-api-python-client`
#
# Once this is configured, you can use your API key in the code below, which would return data on all YouTube videos posted by the [University of Sydney on YouTube](https://www.youtube.com/channel/UChyxYzq0ZAB0iBw-A1l5jFA).

# %%
API_KEY = "?" # your api key here
CHANNEL_ID = "UChyxYzq0ZAB0iBw-A1l5jFA"
pageToken = ""

url = "https://www.googleapis.com/youtube/v3/search?key="+\
API_KEY+"&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=10000"+pageToken
response = requests.get(url).json()
response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'YWu2-qUoWcHoX1f6w2XB6ziA2rg',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'AU',
#  'pageInfo': {'totalResults': 52194, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'KWkBZxkNEY55O7srG-K1eD7XrkM',
#    'id': {'kind': 'youtube#video', 'videoId': 'IgmjUhrnWsc'},
#    'snippet': {'publishedAt': '2025-03-03T20:54:00Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'Freedom Ride 60th Anniversary - Discussion Panel Event',
#     'description': 'Subscribe to our channel: http://bit.ly/2czTNH3 Connect with us: Facebook: https://www.facebook.com/sydneyuni Twitter: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/IgmjUhrnWsc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/IgmjUhrnWsc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/IgmjUhrnWsc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-03-03T20:54:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'hPgn8x6n_gFBPZ6i5b1Ha7NGhcU',
#    'id': {'kind': 'youtube#video', 'videoId': '6aX-fMIxmUA'},
#    'snippet': {'publishedAt': '2025-02-16T21:45:05Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'University of Sydney and Snow Medical Research Foundation launch the Snow Vision Accelerator',
#     'description': 'The Snow Vision Accelerator is a partnership between the Snow Medical Research Foundation and the University of Sydney, with ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6aX-fMIxmUA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/6aX-fMIxmUA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/6aX-fMIxmUA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-02-16T21:45:05Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'zqD0i0nZqHJSMaRugZ29ryCD2Fg',
#    'id': {'kind': 'youtube#video', 'videoId': 'NoXm_ZjSHjE'},
#    'snippet': {'publishedAt': '2025-02-03T22:22:03Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'Welcome to the University of Sydney 2025',
#     'description': 'Subscribe to our channel: http://bit.ly/2czTNH3 Connect with us: Facebook: https://www.facebook.com/sydneyuni Twitter: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/NoXm_ZjSHjE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/NoXm_ZjSHjE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/NoXm_ZjSHjE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-02-03T22:22:03Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'nVqdBpV_Mvhl-0lnwZ4ZabJHeZ8',
#    'id': {'kind': 'youtube#video', 'videoId': 'mybIGDKeWoE'},
#    'snippet': {'publishedAt': '2025-02-02T22:10:44Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'Our 2025 Welcome Program',
#     'description': "Welcome 2025 is just around the corner and we're buzzing with anticipation to welcome everyone! Mark your calendars for the ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mybIGDKeWoE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/mybIGDKeWoE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/mybIGDKeWoE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-02-02T22:10:44Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'M_axxEv147hGiZGP7493o1sbBZc',
#    'id': {'kind': 'youtube#video', 'videoId': '-76zysfF4XI'},
#    'snippet': {'publishedAt': '2025-01-23T03:00:00Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'Essential tips for starting university: Insights from Eddie Woo and Cameryn Smider',
#     'description': 'Are you ready to transition from high school to university? High school teacher and Professor of Practice at The University of ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-76zysfF4XI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/-76zysfF4XI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/-76zysfF4XI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-01-23T03:00:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Y8WHcUv6ZfsO8_00QTMf_WUi9FY',
#    'id': {'kind': 'youtube#video', 'videoId': 'AQTzs6Cpc6k'},
#    'snippet': {'publishedAt': '2024-12-12T01:10:32Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'The Nicholas Catchlove Lecture 2024 | Professor Giles Yeo | Is obesity a choice?',
#     'description': 'The Nicholas Catchlove Lecture 2024 is an annual event generously supported by Dr Barry Catchlove in memory of his son, and ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/AQTzs6Cpc6k/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/AQTzs6Cpc6k/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/AQTzs6Cpc6k/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-12-12T01:10:32Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'FtNxj8biq2YY1Dxi8jeL1YJIPvk',
#    'id': {'kind': 'youtube#video', 'videoId': 'BMh8NCDcRKM'},
#    'snippet': {'publishedAt': '2024-12-05T22:42:01Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'The Integrative Nutrition Seminar Series | Dr Ana Clara Duran',
#     'description': "The Charles Perkins Centre's The Integrative Nutrition Seminar Series brings together all fields of research in nutrition science as ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BMh8NCDcRKM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/BMh8NCDcRKM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/BMh8NCDcRKM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-12-05T22:42:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'gohunM8iPFM5iS4kSXFd5YFWUJQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'hEjhJ6iWTnM'},
#    'snippet': {'publishedAt': '2024-11-05T02:05:41Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'CPC Talks | A clinician&#39;s experience with severe obesity',
#     'description': "Presented by Dr Kathryn Williams, leader of CPC's Lifespan Obesity project node, and recipient of CPC Jennie Mackenzie ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hEjhJ6iWTnM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/hEjhJ6iWTnM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/hEjhJ6iWTnM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-11-05T02:05:41Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'PeUi5wzXy5R3BIXDbBpaOHJdl34',
#    'id': {'kind': 'youtube#video', 'videoId': 'Ii5ERTXPjfw'},
#    'snippet': {'publishedAt': '2024-11-05T01:55:11Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'Loneliness and social isolation: Professor Melody Ding in conversation with Ms Sana Qadar',
#     'description': 'Loneliness and social isolation: A private experience or public health issue? Loneliness seems to be a modern scourge, and on ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Ii5ERTXPjfw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Ii5ERTXPjfw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Ii5ERTXPjfw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-11-05T01:55:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'oNyQ9xgqUCbNLLYx8DkWpHD6HM4',
#    'id': {'kind': 'youtube#video', 'videoId': 'lF92OqnqmFY'},
#    'snippet': {'publishedAt': '2024-11-04T01:47:53Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'Piadora Rahme: &quot;Making my dream a reality&quot;',
#     'description': "Piadora's early experiences ignited her interest in Law. With scholarships and internships, she's now fighting injustice.",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/lF92OqnqmFY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/lF92OqnqmFY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/lF92OqnqmFY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-11-04T01:47:53Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'vEx9dqzSjV_0U_iSg4Ufq09nits',
#    'id': {'kind': 'youtube#video', 'videoId': '4Iad2J_OWeQ'},
#    'snippet': {'publishedAt': '2024-11-04T01:44:22Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'Cedric Danso-Boam : &quot;The world is my campus&quot;',
#     'description': "Cedric's global exchanges and internships in Denmark, Japan and remote Australia shaped his dreams of changing lives.",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4Iad2J_OWeQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/4Iad2J_OWeQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/4Iad2J_OWeQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-11-04T01:44:22Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Jxassmcxo8os0WE2Ss7LudHwdEo',
#    'id': {'kind': 'youtube#video', 'videoId': 'u0l6NNKedFg'},
#    'snippet': {'publishedAt': '2024-11-04T01:42:24Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'Study a flexible degree at USYD #USYD #UniversityOfSydney  #SydneyUni',
#     'description': 'For Boston, a degree in economics and philosophy opened doors to unforgettable opportunities—and even romance. A grant took ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/u0l6NNKedFg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/u0l6NNKedFg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/u0l6NNKedFg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-11-04T01:42:24Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '3MZqifGgttYx0idEZLK7BbipQCY',
#    'id': {'kind': 'youtube#video', 'videoId': 'NUHzF4lt9Y4'},
#    'snippet': {'publishedAt': '2024-11-04T01:42:15Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'Getting an internship at Vogue #USYD #UniversityOfSydney #SydneyUni',
#     'description': "Maeve's journey at the University of Sydney led her to an incredible opportunity: an internship at Vogue Australia. Now, with an ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/NUHzF4lt9Y4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/NUHzF4lt9Y4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/NUHzF4lt9Y4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-11-04T01:42:15Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'WbgIAOTT1nXWLB00rPVTzWcIg1A',
#    'id': {'kind': 'youtube#video', 'videoId': 'oQ5PEPRQQP0'},
#    'snippet': {'publishedAt': '2024-11-04T01:42:19Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'Find your community at USYD #USYD #UniversityOfSydney #SydneyUni',
#     'description': 'Danielle, a proud university alumna, shares her inspiring journey from Southwest Sydney to finding her true community at ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/oQ5PEPRQQP0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/oQ5PEPRQQP0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/oQ5PEPRQQP0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-11-04T01:42:19Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'L2YELKw90TkVkbuA6T31iBRvHSI',
#    'id': {'kind': 'youtube#video', 'videoId': 'OI20ACKq6fk'},
#    'snippet': {'publishedAt': '2024-11-04T01:42:07Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'Turn your passion into a career #USYD #UniversityOfSydney #SydneyUni',
#     'description': 'Meet Danielle, who always had a knack for fixing things and a love for science and math. But it was her passion for history and ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/OI20ACKq6fk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/OI20ACKq6fk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/OI20ACKq6fk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-11-04T01:42:07Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'iylMhywi038xBeYGye6i95JgbLQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'Do7-agO4hcc'},
#    'snippet': {'publishedAt': '2024-11-04T01:42:11Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'Getting an internship at Vogue #USYD #UniversityOfSydney #SydneyUni',
#     'description': "Maeve's journey at the University of Sydney led her to an incredible opportunity: an internship at Vogue Australia. Now, with an ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Do7-agO4hcc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Do7-agO4hcc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Do7-agO4hcc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-11-04T01:42:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'dnLZg8CGqpMJzJGSC9h_1O192iw',
#    'id': {'kind': 'youtube#video', 'videoId': 'ymQF6KUEe1E'},
#    'snippet': {'publishedAt': '2024-11-04T00:54:53Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'Boston: &quot;My life-changing adventure&quot;',
#     'description': "Boston never imagined he'd attend university, let alone study halfway across the world. A life-changing scholarship opened doors.",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ymQF6KUEe1E/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ymQF6KUEe1E/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ymQF6KUEe1E/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-11-04T00:54:53Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Qmbm9SyzBnlaoW48OXaT0j4CoMU',
#    'id': {'kind': 'youtube#video', 'videoId': 'itNnpBax0Mc'},
#    'snippet': {'publishedAt': '2024-11-04T00:54:57Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'Let&#39;s make it happen',
#     'description': "We turn ambition into action. For over 170 years we've empowered brilliant minds to improve their lives and communities.",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/itNnpBax0Mc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/itNnpBax0Mc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/itNnpBax0Mc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-11-04T00:54:57Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'efydp0aNgnJyX1osX9WWG418dL0',
#    'id': {'kind': 'youtube#video', 'videoId': 'zKNWBSbXuDU'},
#    'snippet': {'publishedAt': '2024-11-02T05:00:06Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'The 2024 Dr Charles Perkins Oration, delivered by Joshua Creamer - AUSLAN',
#     'description': 'Subscribe to our channel: http://bit.ly/2czTNH3 Connect with us: Facebook: https://www.facebook.com/sydneyuni Twitter: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zKNWBSbXuDU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/zKNWBSbXuDU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/zKNWBSbXuDU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-11-02T05:00:06Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'UFktuU8P-9l5b5VS1HT9M75X3LE',
#    'id': {'kind': 'youtube#video', 'videoId': 'bMrWgU12kKA'},
#    'snippet': {'publishedAt': '2024-10-23T04:14:26Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'USYD&#39;s Australians of Year: Saving Lives',
#     'description': 'University of Sydney Professor Richard Scolyer AO remains cancer-free, a year after undergoing a world-first treatment for brain ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/bMrWgU12kKA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/bMrWgU12kKA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/bMrWgU12kKA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-10-23T04:14:26Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'h3PXozfbwWk4upSq2zxz1KXCVhA',
#    'id': {'kind': 'youtube#video', 'videoId': '0g2E51VDlkE'},
#    'snippet': {'publishedAt': '2024-09-26T04:09:52Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'Winch lecture 2024 - &#39;Fire&#39; by Victor Steffensen',
#     'description': 'Subscribe to our channel: http://bit.ly/2czTNH3 Connect with us: Facebook: https://www.facebook.com/sydneyuni Twitter: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0g2E51VDlkE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/0g2E51VDlkE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/0g2E51VDlkE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-09-26T04:09:52Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'SHQwWt5sv0OI9CSr4MN2SO4EjsQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'wQzedZx64V0'},
#    'snippet': {'publishedAt': '2024-08-29T04:24:35Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'Veggie power bowl',
#     'description': 'Serves 5 Ingredients: - 250g Kimchi - 230g Cooked black beans - 200g Cherry tomatoes, halved - 2 Cucumber, sliced - 280g ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/wQzedZx64V0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/wQzedZx64V0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/wQzedZx64V0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-08-29T04:24:35Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'LgZ-qo1nq8YtrLLbqlkhJH22M-4',
#    'id': {'kind': 'youtube#video', 'videoId': 'AFTSVVKwA_o'},
#    'snippet': {'publishedAt': '2024-08-25T22:06:09Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'NAIDOC Week 2024 - Fireside Yarn with Elders - 21min version',
#     'description': 'Subscribe to our channel: http://bit.ly/2czTNH3 Connect with us: Instagram: https://instagram.com/sydney_uni TikTok: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/AFTSVVKwA_o/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/AFTSVVKwA_o/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/AFTSVVKwA_o/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-08-25T22:06:09Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'jVziB_3ek6pF0spsgNH9qcaMxl8',
#    'id': {'kind': 'youtube#video', 'videoId': 'uf4ChTLGA14'},
#    'snippet': {'publishedAt': '2024-07-23T22:19:36Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'NAIDOC Week 2024 - highlights',
#     'description': 'Subscribe to our channel: http://bit.ly/2czTNH3 Connect with us: Instagram: https://instagram.com/sydney_uni TikTok: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/uf4ChTLGA14/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/uf4ChTLGA14/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/uf4ChTLGA14/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-07-23T22:19:36Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Jjj3M51NmRTSRghcLm6F_6NBi4c',
#    'id': {'kind': 'youtube#video', 'videoId': 'gioXCZo5jjg'},
#    'snippet': {'publishedAt': '2024-07-22T04:07:13Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'New antidote for cobra bites discovered #antivenom #cobra #science',
#     'description': 'A cheap and accessible drug could help reduce impact of snakebites worldwide. Scientists at the University of Sydney and ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/gioXCZo5jjg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/gioXCZo5jjg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/gioXCZo5jjg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-07-22T04:07:13Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'k8ER6hniLJg3y6Sm-XlqCYid_FQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'ASaWxc7RsDk'},
#    'snippet': {'publishedAt': '2024-07-15T23:39:08Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'Lentil bolognese',
#     'description': 'Serves 4-6 Ingredients: • 200g split red lentils • 3 tbsp extra virgin olive oil • 1 medium brown onion • 1 medium carrot • 1 celery ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ASaWxc7RsDk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ASaWxc7RsDk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ASaWxc7RsDk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-07-15T23:39:08Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'F0dEIUIQLvY4iQDJ4HQh4E9l3a8',
#    'id': {'kind': 'youtube#video', 'videoId': '6XKkc9ITkQo'},
#    'snippet': {'publishedAt': '2024-07-08T05:00:05Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'How can we make the housing system fairer for tenants?',
#     'description': 'Dr Sophia Maalsen and a team of housing researchers at the University of Sydney created the Know Your Landlord Universe to ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6XKkc9ITkQo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/6XKkc9ITkQo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/6XKkc9ITkQo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-07-08T05:00:05Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'nInP7_o-fWBDCxYfPJuYdlVlDvU',
#    'id': {'kind': 'youtube#video', 'videoId': 'f7G8FkJ7ufQ'},
#    'snippet': {'publishedAt': '2024-07-04T22:43:04Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'NAIDOC Week 2024 Fireside Yarn',
#     'description': 'Subscribe to our channel: http://bit.ly/2czTNH3 Connect with us: Instagram: https://instagram.com/sydney_uni TikTok: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/f7G8FkJ7ufQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/f7G8FkJ7ufQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/f7G8FkJ7ufQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-07-04T22:43:04Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '1-dbVjsqtiO-77xs5KhX4GeIrq4',
#    'id': {'kind': 'youtube#video', 'videoId': 'sQXqPsrRb64'},
#    'snippet': {'publishedAt': '2024-06-17T00:43:01Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'Green shakshuka',
#     'description': 'Serves 4 Ingredients: • 2.5 tbsp extra virgin olive oil • 300g Spinach 350g • Vegetable stock • 3 Leeks 1 • Small Onion • 3 large ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/sQXqPsrRb64/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/sQXqPsrRb64/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/sQXqPsrRb64/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-06-17T00:43:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'qK2ZdsuBahOrh970X8ukuG9OiNs',
#    'id': {'kind': 'youtube#video', 'videoId': 'CUiJAtd6Ehw'},
#    'snippet': {'publishedAt': '2024-06-05T21:29:34Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'Gadigal Ngura',
#     'description': 'Subscribe to our channel: http://bit.ly/2czTNH3 Connect with us: Instagram: https://instagram.com/sydney_uni TikTok: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/CUiJAtd6Ehw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/CUiJAtd6Ehw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/CUiJAtd6Ehw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-06-05T21:29:34Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'i21-ejj8KfDcEw07vd2KMpaKs20',
#    'id': {'kind': 'youtube#video', 'videoId': '-ItFirZflPE'},
#    'snippet': {'publishedAt': '2024-06-05T03:59:11Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'Mabo Day 2024 - Toby Cedar, Torres Strait Islander Artist.',
#     'description': 'Subscribe to our channel: http://bit.ly/2czTNH3 Connect with us: Instagram: https://instagram.com/sydney_uni TikTok: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-ItFirZflPE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/-ItFirZflPE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/-ItFirZflPE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-06-05T03:59:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Sn7MJERilzOSvh9XAvTScg5i59A',
#    'id': {'kind': 'youtube#video', 'videoId': 'TzEPxrnCtgI'},
#    'snippet': {'publishedAt': '2024-05-27T02:00:12Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'How much do you know about National Reconciliation Week #NRW2024 #NowMoreThanEver #USYD',
#     'description': 'This week is National Reconciliation Week, a time to reflect on our action towards achieving reconciliation and for celebrating the ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/TzEPxrnCtgI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/TzEPxrnCtgI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/TzEPxrnCtgI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-05-27T02:00:12Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '9gUE9Ekjm_04tF4kenXiVuISLnM',
#    'id': {'kind': 'youtube#video', 'videoId': 'mSKR2XTlwj0'},
#    'snippet': {'publishedAt': '2024-05-26T21:44:02Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'National Reconciliation Week: Now More Than Ever.',
#     'description': 'Subscribe to our channel: http://bit.ly/2czTNH3 Connect with us: Instagram: https://instagram.com/sydney_uni TikTok: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mSKR2XTlwj0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/mSKR2XTlwj0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/mSKR2XTlwj0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-05-26T21:44:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'm10w_LiDPD_wAE_et39ySM-l4PM',
#    'id': {'kind': 'youtube#video', 'videoId': 'fPcb7DNBfFA'},
#    'snippet': {'publishedAt': '2024-05-24T01:00:14Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'Sydney Con student Bailey Pickles made some music for Vivid Sydney #USYD #BaileyPickles #VividSydney',
#     'description': 'Bailey Pickles is lighting up the city TikTok maestro and third-year Sydney Conservatorium of Music student Bailey Pickles has ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fPcb7DNBfFA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/fPcb7DNBfFA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/fPcb7DNBfFA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-05-24T01:00:14Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'eF5U281ZwsDhf8zX0IpFSGteaZs',
#    'id': {'kind': 'youtube#video', 'videoId': 'LKET0HlDpME'},
#    'snippet': {'publishedAt': '2024-05-14T23:13:56Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'A sustainability revolution at USYD&#39;s Net Zero Institute #netzero #sustainability #usyd',
#     'description': 'Virtual power plants, green steel and low-emissions aviation fuel all form part of an ideal future envisaged by the team at the new ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LKET0HlDpME/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/LKET0HlDpME/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/LKET0HlDpME/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-05-14T23:13:56Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'H-SeUGYPF5p9s-IWH-XqVQCJNpA',
#    'id': {'kind': 'youtube#video', 'videoId': '1KdNZqaei2A'},
#    'snippet': {'publishedAt': '2024-05-13T07:07:10Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'The University of Sydney Net Zero Institute',
#     'description': "The University of Sydney's Net Zero Institute brings together more than 150 researchers from across the University to develop ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/1KdNZqaei2A/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/1KdNZqaei2A/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/1KdNZqaei2A/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-05-13T07:07:10Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'wNXdKpsjRnx5e4kWovkENARqRDE',
#    'id': {'kind': 'youtube#video', 'videoId': 'KNuVeHEZhnk'},
#    'snippet': {'publishedAt': '2024-04-26T02:00:06Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'Using social media to talk to young people about health',
#     'description': 'Have you ever searched socials for health information? Here are five things PhD candidate Melody Taba learnt studying how ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/KNuVeHEZhnk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/KNuVeHEZhnk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/KNuVeHEZhnk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-04-26T02:00:06Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'PeGTGmQK5E7vZPupva3tGBjCOk4',
#    'id': {'kind': 'youtube#video', 'videoId': 'u0EFvEZtfbI'},
#    'snippet': {'publishedAt': '2024-04-23T23:51:46Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'ANZAC Day message 2024',
#     'description': 'Join Professor Lisa Jackson Pulver as she shares a heartfelt 2024 ANZAC Day message, inviting us all to pause and reflect on the ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/u0EFvEZtfbI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/u0EFvEZtfbI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/u0EFvEZtfbI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-04-23T23:51:46Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'MC6YFXCTmUXRsdTj74fZXfK1YGA',
#    'id': {'kind': 'youtube#video', 'videoId': 'LjVQOJeVg7g'},
#    'snippet': {'publishedAt': '2024-04-09T14:00:23Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'Spiced, roasted edamame',
#     'description': 'CPC RPA Health for Life Program: Recipes for longevity and healthy living | Broccoli and Parmesan bruschetta Looking for a ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LjVQOJeVg7g/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/LjVQOJeVg7g/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/LjVQOJeVg7g/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-04-09T14:00:23Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'sgJ3bXgPK6DBf__zRVcCL8Bq_Ng',
#    'id': {'kind': 'youtube#video', 'videoId': '_K0YrwNn4AQ'},
#    'snippet': {'publishedAt': '2024-04-09T05:53:25Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'Unlocking the power of global partnerships',
#     'description': 'The Office of Global and Research Engagement builds connections with industry, communities, universities and research ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_K0YrwNn4AQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/_K0YrwNn4AQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/_K0YrwNn4AQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-04-09T05:53:25Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'GH4ykx9QaRwL5QsoiEjsfZHEUKI',
#    'id': {'kind': 'youtube#video', 'videoId': 'dJDBQJnXcBA'},
#    'snippet': {'publishedAt': '2024-04-03T04:02:27Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'International students try Aussie snacks (part three) #university #InternationalStudents #australia',
#     'description': 'We asked our international students to try some Aussie classics. From Tim Tams to Shapes, how would they rate them this time?',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/dJDBQJnXcBA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/dJDBQJnXcBA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/dJDBQJnXcBA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-04-03T04:02:27Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '8Gjqew1PpoVUziTiUqiP9S4KLT4',
#    'id': {'kind': 'youtube#playlist',
#     'playlistId': 'PLXSDVg9HvDBg-BizdeMsMlkm0ejr27OyC'},
#    'snippet': {'publishedAt': '2024-03-28T04:22:45Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'Health for Life recipes',
#     'description': 'The CPC RPA Health for Life Program is a partnership between University of Sydney Charles Perkins Centre and Sydney Local ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/wQzedZx64V0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/wQzedZx64V0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/wQzedZx64V0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-03-28T04:22:45Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'SVud2Ke917UUiR-1PUFcbqHPnZ8',
#    'id': {'kind': 'youtube#video', 'videoId': 'mflrIht6Q0c'},
#    'snippet': {'publishedAt': '2024-03-21T23:42:39Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'International students try Aussie snacks (part two) #university #internationalstudents #australia',
#     'description': 'We asked our international students to try some iconic Aussie snacks for the first time. Subscribe to our channel: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mflrIht6Q0c/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/mflrIht6Q0c/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/mflrIht6Q0c/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-03-21T23:42:39Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 's_57uwuY03iHg45cOLzvIIPbjXU',
#    'id': {'kind': 'youtube#video', 'videoId': '6v0T23dREjk'},
#    'snippet': {'publishedAt': '2024-03-08T01:00:03Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'Things I learned studying astrophysics #usyd #astrophysics #top5',
#     'description': 'Did you know that your body is made of dead stars? Here are five things PhD candidate Nada Salama learned studying ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6v0T23dREjk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/6v0T23dREjk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/6v0T23dREjk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-03-08T01:00:03Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'WJgCjLUibssPK89k8kH9uhcJAR8',
#    'id': {'kind': 'youtube#video', 'videoId': 'QAoNnWQMCBI'},
#    'snippet': {'publishedAt': '2024-03-07T21:45:00Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'Creating opportunities for all with Science in Australia Gender Equity (SAGE) program at Sydney',
#     'description': 'The Science in Australia Gender Equity (SAGE) program works to change policies and practices at the University of Sydney to ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/QAoNnWQMCBI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/QAoNnWQMCBI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/QAoNnWQMCBI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-03-07T21:45:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '6IFYUYuIQwzF-qJI6mecupe6FeU',
#    'id': {'kind': 'youtube#video', 'videoId': 'jQud5C_UKxU'},
#    'snippet': {'publishedAt': '2024-03-05T04:00:14Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'International students try Aussie snacks (part one) #university #internationalstudents #australia',
#     'description': 'We asked our international students to try some iconic Aussie snacks for the first time. Subscribe to our channel: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/jQud5C_UKxU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/jQud5C_UKxU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/jQud5C_UKxU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-03-05T04:00:14Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'rLWveY3Om8iDa7YSuqrhZDEE9do',
#    'id': {'kind': 'youtube#video', 'videoId': 'CgEKfSAa1PE'},
#    'snippet': {'publishedAt': '2024-03-01T05:38:48Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'Guess my major #university #major #USYD',
#     'description': 'Can you guess what these students study, just by looking at a photo of them? Subscribe to our channel: http://bit.ly/2czTNH3 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/CgEKfSAa1PE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/CgEKfSAa1PE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/CgEKfSAa1PE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-03-01T05:38:48Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'W3WTn0lhHpZIGw6OIgJ03bw2uOc',
#    'id': {'kind': 'youtube#video', 'videoId': 'glTje8KfvFk'},
#    'snippet': {'publishedAt': '2024-02-28T01:46:29Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'Save the date: Alumni Festival 2024',
#     'description': 'SAVE THE DATE: 30 November 2024 In 2023 the University of Sydney launched their inaugural Alumni Festival. The festival ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/glTje8KfvFk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/glTje8KfvFk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/glTje8KfvFk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-02-28T01:46:29Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'VwOwz6rtqx-wAdGWdhRVBnng7Uw',
#    'id': {'kind': 'youtube#video', 'videoId': 'pYOxyQO4fFM'},
#    'snippet': {'publishedAt': '2024-02-27T03:00:34Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'Hidden Disabilities: Sunflower Initiative #HiddenDisabilitiesSunflower #WearTheSunflower #USYD',
#     'description': "What is the Sunflower Initiative? We asked a USYD staff member just that. If you're a USYD student with a hidden disability and ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/pYOxyQO4fFM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/pYOxyQO4fFM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/pYOxyQO4fFM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-02-27T03:00:34Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'RsUAdkLHtC-DMD9wBfLG1FrumDo',
#    'id': {'kind': 'youtube#video', 'videoId': 'OsjXU9Ju_J0'},
#    'snippet': {'publishedAt': '2024-02-22T22:00:20Z',
#     'channelId': 'UChyxYzq0ZAB0iBw-A1l5jFA',
#     'title': 'Eddie Woo: Ask Me Anything',
#     'description': 'Mr Eddie Woo - Professor of Practice at The University of Sydney, Wootube mastermind, author, TED speaker, and TV host - is ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/OsjXU9Ju_J0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/OsjXU9Ju_J0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/OsjXU9Ju_J0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The University of Sydney',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-02-22T22:00:20Z'}}]}

# %% [markdown]
# We can once more turn this into a dataframe:

# %%
pd.json_normalize(response['items']).head()
# Out:
#                    kind                         etag        id.kind  \
# 0  youtube#searchResult  KWkBZxkNEY55O7srG-K1eD7XrkM  youtube#video
# 1  youtube#searchResult  hPgn8x6n_gFBPZ6i5b1Ha7NGhcU  youtube#video
# 2  youtube#searchResult  zqD0i0nZqHJSMaRugZ29ryCD2Fg  youtube#video
# 3  youtube#searchResult  nVqdBpV_Mvhl-0lnwZ4ZabJHeZ8  youtube#video
# 4  youtube#searchResult  M_axxEv147hGiZGP7493o1sbBZc  youtube#video
#
#     id.videoId   snippet.publishedAt         snippet.channelId  \
# 0  IgmjUhrnWsc  2025-03-03T20:54:00Z  UChyxYzq0ZAB0iBw-A1l5jFA
# 1  6aX-fMIxmUA  2025-02-16T21:45:05Z  UChyxYzq0ZAB0iBw-A1l5jFA
# 2  NoXm_ZjSHjE  2025-02-03T22:22:03Z  UChyxYzq0ZAB0iBw-A1l5jFA
# 3  mybIGDKeWoE  2025-02-02T22:10:44Z  UChyxYzq0ZAB0iBw-A1l5jFA
# 4  -76zysfF4XI  2025-01-23T03:00:00Z  UChyxYzq0ZAB0iBw-A1l5jFA
#
#                                        snippet.title  \
# 0  Freedom Ride 60th Anniversary - Discussion Pan...
# 1  University of Sydney and Snow Medical Research...
# 2           Welcome to the University of Sydney 2025
# 3                           Our 2025 Welcome Program
# 4  Essential tips for starting university: Insigh...
#
#                                  snippet.description  \
# 0  Subscribe to our channel: http://bit.ly/2czTNH...
# 1  The Snow Vision Accelerator is a partnership b...
# 2  Subscribe to our channel: http://bit.ly/2czTNH...
# 3  Welcome 2025 is just around the corner and we'...
# 4  Are you ready to transition from high school t...
#
#                    snippet.thumbnails.default.url  \
# 0  https://i.ytimg.com/vi/IgmjUhrnWsc/default.jpg
# 1  https://i.ytimg.com/vi/6aX-fMIxmUA/default.jpg
# 2  https://i.ytimg.com/vi/NoXm_ZjSHjE/default.jpg
# 3  https://i.ytimg.com/vi/mybIGDKeWoE/default.jpg
# 4  https://i.ytimg.com/vi/-76zysfF4XI/default.jpg
#
#    snippet.thumbnails.default.width  ...  \
# 0                               120  ...
# 1                               120  ...
# 2                               120  ...
# 3                               120  ...
# 4                               120  ...
#
#                       snippet.thumbnails.medium.url  \
# 0  https://i.ytimg.com/vi/IgmjUhrnWsc/mqdefault.jpg
# 1  https://i.ytimg.com/vi/6aX-fMIxmUA/mqdefault.jpg
# 2  https://i.ytimg.com/vi/NoXm_ZjSHjE/mqdefault.jpg
# 3  https://i.ytimg.com/vi/mybIGDKeWoE/mqdefault.jpg
# 4  https://i.ytimg.com/vi/-76zysfF4XI/mqdefault.jpg
#
#   snippet.thumbnails.medium.width  snippet.thumbnails.medium.height  \
# 0                             320                               180
# 1                             320                               180
# 2                             320                               180
# 3                             320                               180
# 4                             320                               180
#
#                         snippet.thumbnails.high.url  \
# 0  https://i.ytimg.com/vi/IgmjUhrnWsc/hqdefault.jpg
# 1  https://i.ytimg.com/vi/6aX-fMIxmUA/hqdefault.jpg
# 2  https://i.ytimg.com/vi/NoXm_ZjSHjE/hqdefault.jpg
# 3  https://i.ytimg.com/vi/mybIGDKeWoE/hqdefault.jpg
# 4  https://i.ytimg.com/vi/-76zysfF4XI/hqdefault.jpg
#
#   snippet.thumbnails.high.width  snippet.thumbnails.high.height  \
# 0                           480                             360
# 1                           480                             360
# 2                           480                             360
# 3                           480                             360
# 4                           480                             360
#
#        snippet.channelTitle snippet.liveBroadcastContent  \
# 0  The University of Sydney                         none
# 1  The University of Sydney                         none
# 2  The University of Sydney                         none
# 3  The University of Sydney                         none
# 4  The University of Sydney                         none
#
#     snippet.publishTime id.playlistId
# 0  2025-03-03T20:54:00Z           NaN
# 1  2025-02-16T21:45:05Z           NaN
# 2  2025-02-03T22:22:03Z           NaN
# 3  2025-02-02T22:10:44Z           NaN
# 4  2025-01-23T03:00:00Z           NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# Now, let's leverage `googleapiclient` so that we can send parameters to YouTube for our search query, in this case, for the Will Smith video:

# %%
import googleapiclient
import googleapiclient.discovery

api_service_name = "youtube"
api_version = "v3"

youtube = googleapiclient.discovery.build(api_service_name, api_version, developerKey = API_KEY)

request = youtube.search().list(
        part="id,snippet",
        type='video',
        q="Will Smith Chris Rock",
        videoDefinition='high',
        maxResults=10
)

response = request.execute()

# %%
pd.json_normalize(response['items'])[['id.videoId','snippet.title', 'snippet.description', 'snippet.channelTitle']]
# Out:
#     id.videoId                                      snippet.title  \
# 0  myjEoDypUD8  Watch the uncensored moment Will Smith smacks ...
# 1  Z8LtP1GsoeA  Will Smith slaps Chris Rock at the 2022 Oscars...
# 2  rZohnqfJ9W0    Will Smith Speaks Out About Slapping Chris Rock
# 3  Od_s2CMeWWE                      Chris Rock on Will Smith slap
# 4  z4t1CC7-UFE         Will Smith SLAPS Chris Rock at Oscars 2022
# 5  LX2dDI1KkQ8  Jada Pinkett Smith addresses Will slapping Chr...
# 6  _HML6UYYF-I              The Talk: Will Smith &amp; Chris Rock
# 7  d1DiebCapDs  Adam Sandler On Will Smith Slapping Chris Rock...
# 8  hd1wdi0RK2w  Chris Rock TORCHES Woke Hollywood – They Can’t...
# 9  NRlkVb-kSrM  Will Smith Slaps Chris Rock On Oscars 2022 Sta...
#
#                                  snippet.description   snippet.channelTitle
# 0  Best actor nominee Will Smith appeared to slap...          Guardian News
# 1  The full clip of the moment Chris Rock was sla...              SimonTime
# 2  After slapping Chris Rock at the Oscars, Will ...               NBC News
# 3  Socials --------------------------------------...              HAVE-CTRL
# 4  Will Smith did not seem to find Chris Rock's j...  Entertainment Tonight
# 5  Sitting down with TODAY's Hoda Kotb, Jada Pink...                  TODAY
# 6  Video by Jonas Hollerup Helle https://www.inst...               THE TALK
# 7  If you like what we do, please feel free to su...      University Of JRE
# 8  Chris Rock TORCHES Woke Hollywood – They Can't...             Woke Break
# 9  Republic TV is India's no.1 English news chann...         Republic World

# %% [markdown]
# **Task: Extract comments from the top video above.**
#
# Try extracting 100 comments from the top video listed above.
#
# Hint: Use the Youtube Data API Documentation and look into commentThreads.

# %%
### TO DO
request = youtube.commentThreads().list(
    part="snippet",
    videoId="myjEoDypUD8",
    maxResults=100
)
response = request.execute()

pd.json_normalize(response['items'])[['snippet.topLevelComment.snippet.textDisplay', 'snippet.topLevelComment.snippet.likeCount']]
# Out:
#           snippet.topLevelComment.snippet.textDisplay  \
# 0   Will Smith wins best actor Oscar for King Rich...
# 1   Will smith is a real igga he couldn’t get it o...
# 2                    Will Smith is a peace of garbage
# 3   This was the most awkward thing I’ve ever expe...
# 4   The Oscar’s clearly a watch anything happen to...
# ..                                                ...
# 95  For awhile I thought he said &quot;keep my whi...
# 96  <a href="https://www.youtube.com/watch?v=myjEo...
# 97  Bro used every face muscle to tell Chris Rock ...
# 98                      I still remember this sad day
# 99          his wife had a taste of fresh sausage lol
#
#     snippet.topLevelComment.snippet.likeCount
# 0                                       33290
# 1                                           0
# 2                                           0
# 3                                           1
# 4                                           0
# ..                                        ...
# 95                                          0
# 96                                          0
# 97                                          0
# 98                                          1
# 99                                          0
#
# [100 rows x 2 columns]
